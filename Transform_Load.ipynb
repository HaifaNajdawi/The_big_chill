# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from config import password

# %% [markdown]
# ## Merge netflix and omdb csv files

# %%
file = "resources/netflix_titles.csv"
netflix_df = pd.read_csv(file)
file = "resources/omdb_list.csv"
omdb_df = pd.read_csv(file)

# %%
omdb_df.head()
# Out:
#    Unnamed: 0                                    title  \
# 0           0  Norm of the North: King Sized Adventure
# 1           1               Jandino: Whatever it Takes
# 2           2                       Transformers Prime
# 3           3         Transformers: Robots in Disguise
# 4           4                                  Apaches
#
#                                                genre runtime  imdbRating  \
# 0               Animation, Adventure, Comedy, Family  90 min         3.3
# 1                                             Comedy  95 min         4.8
# 2  Animation, Action, Adventure, Comedy, Drama, F...  30 min         7.9
# 3       Animation, Action, Adventure, Comedy, Sci-Fi  22 min         6.0
# 4                                              Drama  82 min         5.9
#
#   imdbVotes                                             poster  \
# 0       311  https://m.media-amazon.com/images/M/MV5BNjMwZD...
# 1        23  https://m.media-amazon.com/images/M/MV5BMWE3MG...
# 2     5,454  https://m.media-amazon.com/images/M/MV5BMTczND...
# 3       842  https://m.media-amazon.com/images/M/MV5BMjMwNT...
# 4       292  https://m.media-amazon.com/images/M/MV5BODYyOT...
#
#                       awards boxoffice        language
# 0                        NaN       NaN         English
# 1                        NaN       NaN  English, Dutch
# 2  14 wins & 26 nominations.       NaN         English
# 3   2 wins & 11 nominations.       NaN         English
# 4             3 nominations.       NaN  French, Arabic

# %%
omdb_unique_df = omdb_df.drop_duplicates(subset=['title'])
print(len(omdb_df))
print(len(omdb_unique_df))
# Out:
# 5473
# 5412

# %%
merged_df = netflix_df.merge(omdb_unique_df, how="left", on="title")
merged_df['imdbVotes']= merged_df['imdbVotes'].str.replace(',', '')
merged_df['imdbVotes']= merged_df['imdbVotes'].fillna(0)
merged_df['imdbVotes']= merged_df['imdbVotes'].astype(int)
print(len(merged_df))
merged_df.head()
# Out:
# 6234
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration  ...                                        description  \
# 0     TV-PG    90 min  ...  Before planning an awesome wedding for his gra...
# 1     TV-MA    94 min  ...  Jandino Asporaat riffs on the challenges of ra...
# 2  TV-Y7-FV  1 Season  ...  With the help of three human allies, the Autob...
# 3     TV-Y7  1 Season  ...  When a prison ship crash unleashes hundreds of...
# 4     TV-14    99 min  ...  When nerdy high schooler Dani finally attracts...
#
#   Unnamed: 0                                              genre runtime  \
# 0        0.0               Animation, Adventure, Comedy, Family  90 min
# 1        1.0                                             Comedy  95 min
# 2        2.0  Animation, Action, Adventure, Comedy, Drama, F...  30 min
# 3        3.0       Animation, Action, Adventure, Comedy, Sci-Fi  22 min
# 4        NaN                                                NaN     NaN
#
#   imdbRating  imdbVotes                                             poster  \
# 0        3.3        311  https://m.media-amazon.com/images/M/MV5BNjMwZD...
# 1        4.8         23  https://m.media-amazon.com/images/M/MV5BMWE3MG...
# 2        7.9       5454  https://m.media-amazon.com/images/M/MV5BMTczND...
# 3        6.0        842  https://m.media-amazon.com/images/M/MV5BMjMwNT...
# 4        NaN          0                                                NaN
#
#                       awards boxoffice        language
# 0                        NaN       NaN         English
# 1                        NaN       NaN  English, Dutch
# 2  14 wins & 26 nominations.       NaN         English
# 3   2 wins & 11 nominations.       NaN         English
# 4                        NaN       NaN             NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Transform netflix genre

# %%
# Turn listed_in into list
merged_df.listed_in = merged_df.listed_in.str.split(',').tolist()
listed_df = merged_df.dropna(subset=['listed_in'])
listed_in = listed_df["listed_in"].tolist()

# %%
# Loop through listed_in (netflix genre) and get unique values into netflix_genre set
netflix_genre = set()

for movie in listed_in:
    for x in movie:
        netflix_genre.add(x)
print(netflix_genre)

netflix_genre_id = pd.DataFrame(netflix_genre, columns=["netflix_genre"])
netflix_genre_id = netflix_genre_id.reset_index()
netflix_genre_id = netflix_genre_id.rename(columns={'index': 'netflix_genre_no'})
netflix_genre_id.head(45)
# Out:
# {'British TV Shows', 'Classic Movies', 'Independent Movies', 'Spanish-Language TV Shows', 'TV Comedies', ' Romantic TV Shows', ' Romantic Movies', ' Docuseries', 'TV Horror', ' International TV Shows', ' Independent Movies', ' Documentaries', 'Anime Series', ' TV Sci-Fi & Fantasy', ' Horror Movies', 'Children & Family Movies', 'Action & Adventure', ' TV Dramas', 'Romantic TV Shows', ' Anime Features', ' Reality TV', ' Stand-Up Comedy', 'Comedies', 'Crime TV Shows', ' Spanish-Language TV Shows', 'Anime Features', 'TV Action & Adventure', 'Music & Musicals', ' Classic & Cult TV', 'Cult Movies', "Kids' TV", ' Teen TV Shows', ' TV Action & Adventure', ' Classic Movies', ' Children & Family Movies', " Kids' TV", ' TV Mysteries', 'Thrillers', ' LGBTQ Movies', 'Stand-Up Comedy', ' Science & Nature TV', ' Thrillers', ' Comedies', 'Classic & Cult TV', ' Faith & Spirituality', 'Horror Movies', ' Dramas', 'International TV Shows', ' Music & Musicals', 'Stand-Up Comedy & Talk Shows', ' TV Comedies', ' TV Thrillers', ' Stand-Up Comedy & Talk Shows', ' Sports Movies', ' Sci-Fi & Fantasy', ' Korean TV Shows', 'TV Shows', 'Documentaries', 'TV Sci-Fi & Fantasy', 'Reality TV', 'TV Dramas', 'Movies', ' International Movies', ' TV Horror', 'Dramas', ' Cult Movies', 'Sports Movies', 'Sci-Fi & Fantasy', 'Romantic Movies', ' Crime TV Shows', 'International Movies', 'Docuseries'}
#     netflix_genre_no               netflix_genre
# 0                  0            British TV Shows
# 1                  1              Classic Movies
# 2                  2          Independent Movies
# 3                  3   Spanish-Language TV Shows
# 4                  4                 TV Comedies
# 5                  5           Romantic TV Shows
# 6                  6             Romantic Movies
# 7                  7                  Docuseries
# 8                  8                   TV Horror
# 9                  9      International TV Shows
# 10                10          Independent Movies
# 11                11               Documentaries
# 12                12                Anime Series
# 13                13         TV Sci-Fi & Fantasy
# 14                14               Horror Movies
# 15                15    Children & Family Movies
# 16                16          Action & Adventure
# 17                17                   TV Dramas
# 18                18           Romantic TV Shows
# 19                19              Anime Features
# 20                20                  Reality TV
# 21                21             Stand-Up Comedy
# 22                22                    Comedies
# 23                23              Crime TV Shows
# 24                24   Spanish-Language TV Shows
# 25                25              Anime Features
# 26                26       TV Action & Adventure
# 27                27            Music & Musicals
# 28                28           Classic & Cult TV
# 29                29                 Cult Movies
# 30                30                    Kids' TV
# 31                31               Teen TV Shows
# 32                32       TV Action & Adventure
# 33                33              Classic Movies
# 34                34    Children & Family Movies
# 35                35                    Kids' TV
# 36                36                TV Mysteries
# 37                37                   Thrillers
# 38                38                LGBTQ Movies
# 39                39             Stand-Up Comedy
# 40                40         Science & Nature TV
# 41                41                   Thrillers
# 42                42                    Comedies
# 43                43           Classic & Cult TV
# 44                44        Faith & Spirituality

# %%
# Break out genres (listed_in) with show_id
listed_in_df = merged_df.loc[:,['show_id', 'listed_in']]
listed_in_df = listed_in_df.explode('listed_in')
listed_in_df = listed_in_df.rename(columns={'listed_in': 'netflix_genre'})
listed_in_df.head()
# Out:
#     show_id             netflix_genre
# 0  81145628  Children & Family Movies
# 0  81145628                  Comedies
# 1  80117401           Stand-Up Comedy
# 2  70234439                  Kids' TV
# 3  80058654                  Kids' TV

# %%
# merge tables to create show_id and genre_id table
netflix_genre_table = listed_in_df.merge(netflix_genre_id,how = "left", on="netflix_genre")
netflix_genre_table = netflix_genre_table.loc[:,['show_id','netflix_genre_no']]
netflix_genre_table.head()
# Out:
#     show_id  netflix_genre_no
# 0  81145628                15
# 1  81145628                42
# 2  80117401                39
# 3  70234439                30
# 4  80058654                30

# %% [markdown]
# ## Transform omdb genre

# %%
# Turn genre into list 
merged_df.genre = merged_df.genre.str.split(',').tolist()
genre_df = merged_df.dropna(subset=['genre'])
genre = genre_df["genre"].tolist()

# %%
# Loop through genre (omdb genre) and get unique values into omdb_genre set
omdb_genre = set()

for movie in genre:
    for y in movie:
        omdb_genre.add(y)
print(omdb_genre)

omdb_genre_id = pd.DataFrame(omdb_genre, columns=["omdb_genre"])
omdb_genre_id = omdb_genre_id.reset_index()
omdb_genre_id = omdb_genre_id.rename(columns={'index': 'omdb_genre_no'})
omdb_genre_id.head()
# Out:
# {' Thriller', ' Romance', ' Animation', ' Crime', ' Action', 'Western', ' Mystery', 'Mystery', ' Reality-TV', 'Short', 'War', 'Comedy', 'Talk-Show', ' Adventure', ' Music', ' Musical', 'Reality-TV', ' Sci-Fi', ' Sport', ' War', 'Fantasy', ' Horror', 'Adventure', 'History', 'Horror', ' Biography', ' Family', ' Comedy', ' Western', 'Thriller', ' Fantasy', 'Animation', 'Music', ' Film-Noir', 'Action', ' Drama', ' Short', 'Musical', ' Documentary', ' Talk-Show', 'Biography', ' Game-Show', 'News', 'Documentary', 'Crime', ' News', ' History', 'Family', 'Sci-Fi', 'Adult', 'Sport', 'Romance', 'Game-Show', 'Drama'}
#    omdb_genre_no  omdb_genre
# 0              0    Thriller
# 1              1     Romance
# 2              2   Animation
# 3              3       Crime
# 4              4      Action

# %%
# Break out genres with show_id
genre_df = merged_df.loc[:,['show_id', 'genre']]
genre_df = genre_df.explode('genre')
genre_df = genre_df.rename(columns={'genre': 'omdb_genre'})
genre_df.dropna(inplace = True)
genre_df.head()
# Out:
#     show_id  omdb_genre
# 0  81145628   Animation
# 0  81145628   Adventure
# 0  81145628      Comedy
# 0  81145628      Family
# 1  80117401      Comedy

# %%
# merge tables to create show_id and genre_id table
omdb_genre_table = genre_df.merge(omdb_genre_id,how = "left", on="omdb_genre")
omdb_genre_table = omdb_genre_table.loc[:,['show_id','omdb_genre_no']]
omdb_genre_table.head()
# Out:
#     show_id  omdb_genre_no
# 0  81145628             31
# 1  81145628             13
# 2  81145628             27
# 3  81145628             26
# 4  80117401             11

# %% [markdown]
# ## Transform language table

# %%
# Turn language into list 
merged_df.language = merged_df.language.str.split(',').tolist()
lan_df = merged_df.dropna(subset=['language'])
language = lan_df["language"].tolist()
language
# Out:
# [['English'],
#  ['English', ' Dutch'],
#  ['English'],
#  ['English'],
#  ['French', ' Arabic'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English', ' Dutch', ' German'],
#  ['Hindi', ' English'],
#  ['English', ' French'],
#  ['English'],
#  ['English'],
#  ['Spanish', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Mandarin'],
#  ['English'],
#  ['French'],
#  ['French'],
#  ['Hindi'],
#  ['Telugu'],
#  ['English', ' Arabic'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Thai'],
#  ['Thai'],
#  ['English'],
#  ['Thai'],
#  ['Thai'],
#  ['Thai'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Urdu'],
#  ['English'],
#  ['English'],
#  ['Tamil'],
#  ['English', ' Swahili', ' Nama', ' Xhosa', ' Korean'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Italian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Portuguese'],
#  ['English'],
#  ['English', ' Swedish', ' French', ' Vietnamese', ' Russian', ' Hebrew'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Indonesian', ' English', ' German'],
#  ['English'],
#  ['English'],
#  ['Japanese'],
#  ['Hindi', ' Mandarin', ' English', ' Italian', ' French', ' Arabic'],
#  ['English'],
#  ['Spanish', ' English'],
#  ['Indonesian'],
#  ['Indonesian'],
#  ['Dutch', ' Minangkabau', ' Indonesian'],
#  ['Spanish', ' Catalan', ' English'],
#  ['English'],
#  ['Hindi'],
#  ['Turkish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Cantonese'],
#  ['Arabic', ' French'],
#  ['English'],
#  ['Hindi'],
#  ['Mandarin', ' Cantonese', ' Japanese'],
#  ['Filipino', ' Tagalog'],
#  ['American Sign Language', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['Vietnamese'],
#  ['English'],
#  ['English', ' Japanese'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' German', ' French', ' Latin'],
#  ['English'],
#  ['Chinese', ' English'],
#  ['English'],
#  ['Spanish'],
#  ['Telugu'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['English', ' Spanish'],
#  ['English', ' Serbo-Croatian', ' Russian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Yoruba', ' English', ' Ibo', ' Hausa'],
#  ['English', ' Yoruba'],
#  ['French', ' Arabic', ' English'],
#  ['Japanese'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['French'],
#  ['German'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Catalan'],
#  ['English'],
#  ['Cantonese'],
#  ['Cantonese'],
#  ['English'],
#  ['English'],
#  ['Thai'],
#  ['Vietnamese', ' English', ' German'],
#  ['Mandarin'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Mandarin'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' French', ' Latin'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Arabic', ' English'],
#  ['English'],
#  ['English', ' Korean'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['English', ' Dutch'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Arabic'],
#  ['English'],
#  ['English'],
#  ['Malayalam'],
#  ['Indonesian'],
#  ['Indonesian'],
#  ['Tamil'],
#  ['English'],
#  ['Hindi', ' Punjabi', ' English'],
#  ['Assamese'],
#  ['Bengali'],
#  ['Bengali'],
#  ['English'],
#  ['Khmer', ' English', ' French'],
#  ['Urdu', ' Pushto'],
#  ['English'],
#  ['Finnish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Polish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Japanese'],
#  ['Spanish'],
#  ['English'],
#  ['English', ' Hebrew', ' Arabic', ' Italian'],
#  ['English'],
#  ['Mandarin'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Japanese'],
#  ['French'],
#  ['Spanish'],
#  ['Mandarin', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Japanese', ' Vietnamese'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Dutch'],
#  ['English'],
#  ['English'],
#  ['English', ' Italian', ' Portuguese'],
#  ['English'],
#  ['English'],
#  ['Japanese'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish', ' Cantonese'],
#  ['English'],
#  ['Russian'],
#  ['English'],
#  ['None'],
#  ['English'],
#  ['English'],
#  ['English', ' Yoruba'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['French', ' Spanish', ' Italian', ' English'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Russian', ' Polish'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['English', ' French', ' Arabic', ' Yoruba', ' Swahili', ' Chinese'],
#  ['English'],
#  ['English', ' Latin'],
#  ['English', ' Russian'],
#  ['English', ' Ukrainian'],
#  ['English'],
#  ['English'],
#  ['Arabic'],
#  ['Arabic'],
#  ['English', ' Hebrew'],
#  ['Mandarin'],
#  ['Spanish', ' Catalan', ' English'],
#  ['English'],
#  ['French'],
#  ['English'],
#  ['English', ' Hindi'],
#  ['Hindi'],
#  ['Hindi'],
#  ['English'],
#  ['Hindi'],
#  ['Thai'],
#  ['English'],
#  ['Spanish', ' English', ' Japanese', ' Latin'],
#  ['French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Armenian', ' German', ' French', ' Turkish'],
#  ['English', ' American Sign Language'],
#  ['Russian'],
#  ['Hindi'],
#  ['French'],
#  ['Japanese', ' English'],
#  ['Japanese', ' English'],
#  ['English'],
#  ['Panjabi'],
#  ['Hindi'],
#  ['Japanese'],
#  ['Japanese'],
#  ['Cantonese', ' Mandarin', ' English'],
#  ['French'],
#  ['Japanese', ' English'],
#  ['Hindi'],
#  ['English'],
#  ['English'],
#  ['Bengali'],
#  ['English'],
#  ['Hindi'],
#  ['Hindi'],
#  ['Japanese'],
#  ['Japanese'],
#  ['Japanese'],
#  ['English'],
#  ['French', ' Hungarian', ' Italian', ' English'],
#  ['English'],
#  ['Punjabi', ' Hindi'],
#  ['Spanish'],
#  ['English'],
#  ['Chinese'],
#  ['English', ' Spanish'],
#  ['Spanish'],
#  ['English', ' Italian'],
#  ['Spanish'],
#  ['Dutch', ' Yiddish', ' English'],
#  ['Dutch'],
#  ['English', ' German'],
#  ['English'],
#  ['Urdu', ' Pushto'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Spanish', ' German'],
#  ['French'],
#  ['Mandarin'],
#  ['Mandarin', ' Min Nan'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Indonesian', ' English'],
#  ['English'],
#  ['Ukrainian', ' Russian', ' English'],
#  ['English'],
#  ['English'],
#  ['Malay', ' English'],
#  ['English', ' Turkish', ' Greek', ' Russian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Irish', ' French'],
#  ['Portuguese'],
#  ['Norwegian', ' Swedish'],
#  ['English'],
#  ['Japanese'],
#  ['Mandarin', ' English'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['Hindi', ' English'],
#  ['Indonesian'],
#  ['English'],
#  ['Japanese'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Turkish'],
#  ['English'],
#  ['Turkish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Indonesian'],
#  ['English'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['Spanish'],
#  ['Filipino', ' Tagalog', ' English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['Tamil'],
#  ['Korean'],
#  ['Korean'],
#  ['English', ' Hindi'],
#  ['Hindi'],
#  ['Marathi'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Punjabi'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Spanish'],
#  ['Japanese', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['French', ' Lingala'],
#  ['Finnish'],
#  ['French'],
#  ['Chinese'],
#  ['English'],
#  ['Cantonese'],
#  ['English'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['Chinese'],
#  ['English'],
#  ['Russian', ' Spanish', ' Finnish'],
#  ['English'],
#  ['Spanish'],
#  ['Spanish'],
#  ['English'],
#  ['Telugu'],
#  ['English'],
#  ['Hebrew', ' English', ' Arabic', ' Russian'],
#  ['English'],
#  ['English'],
#  ['Italian'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['Spanish'],
#  ['French'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['German', ' Yiddish', ' Hebrew'],
#  ['Spanish', ' English'],
#  ['English'],
#  ['English', ' Hindi'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish', ' French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Malay'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' German', ' Arabic', ' Russian', ' French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Cantonese', ' Mandarin', ' English'],
#  ['English'],
#  ['Mandarin'],
#  ['English'],
#  ['English', ' German', ' French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Chinese', ' Vietnamese'],
#  ['English'],
#  ['Hindi', ' English', ' Marathi'],
#  ['Hindi', ' Bengali'],
#  ['Hindi'],
#  ['Hindi', ' Urdu', ' English', ' Arabic'],
#  ['Hindi'],
#  ['Hindi', ' Punjabi', ' English'],
#  ['Hindi', ' English'],
#  ['English', ' Japanese'],
#  ['English'],
#  ['Finnish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Spanish'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['English', ' Yiddish'],
#  ['Spanish', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' German'],
#  ['English', ' Latin'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Spanish', ' English'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English', ' Russian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Telugu'],
#  ['English', ' Cantonese', ' Mandarin'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['Indonesian', ' English', ' Mandarin', ' French'],
#  ['English', ' Swedish', ' Italian', ' Portuguese', ' French'],
#  ['French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Afrikaans'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English', ' Mandarin', ' Spanish', ' Russian'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['Indonesian'],
#  ['Tamil'],
#  ['English', ' Japanese'],
#  ['English'],
#  ['Korean'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['Persian'],
#  ['Chinese'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['Dutch', ' English'],
#  ['English'],
#  ['English', ' Akan'],
#  ['English'],
#  ['Turkish', ' Italian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['Bengali'],
#  ['Hindi'],
#  ['Hindi'],
#  ['Hindi'],
#  ['English'],
#  ['English'],
#  ['Punjabi'],
#  ['Spanish'],
#  ['Hindi'],
#  ['English'],
#  ['Hindi'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['Punjabi'],
#  ['English'],
#  ['Kannada'],
#  ['Hindi'],
#  ['Punjabi'],
#  ['Hindi'],
#  ['Hindi'],
#  ['English'],
#  ['Japanese', ' English'],
#  ['Japanese'],
#  ['English'],
#  ['Japanese'],
#  ['Japanese'],
#  ['Japanese'],
#  ['English', ' French'],
#  ['French'],
#  ['English', ' Mandarin'],
#  ['Italian', ' Romany', ' English'],
#  ['English', ' Spanish'],
#  ['English', ' French'],
#  ['Korean'],
#  ['Hindi'],
#  ['Arabic'],
#  ['Turkish'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Chinese'],
#  ['English'],
#  ['Indonesian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Arabic'],
#  ['Spanish', ' Basque'],
#  ['English'],
#  ['English',
#   ' Persian',
#   ' Urdu',
#   ' Arabic',
#   ' Kurdish',
#   ' Hindi',
#   ' Hungarian'],
#  ['Turkish'],
#  ['English'],
#  ['English'],
#  ['Yoruba', ' Ibo', ' English'],
#  ['Japanese'],
#  ['Korean'],
#  ['Cantonese'],
#  ['English'],
#  ['English'],
#  ['Polish', ' Danish'],
#  ['English'],
#  ['English', ' Russian'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish', ' Russian'],
#  ['English'],
#  ['English'],
#  ['English', ' German', ' Finnish', ' Japanese', ' Cantonese'],
#  ['English', ' Mandarin', ' Spanish'],
#  ['Korean'],
#  ['Korean'],
#  ['Hindi'],
#  ['English', ' Persian', ' Spanish', ' Mandarin', ' Korean'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['Polish'],
#  ['English'],
#  ['Thai'],
#  ['Hindi'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Polish', ' German'],
#  ['English'],
#  ['English', ' Russian', ' Italian', ' Mandarin', ' French'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['Korean', ' English'],
#  ['English'],
#  ['English'],
#  ['English', ' Mandarin', ' Spanish', ' French'],
#  ['English', ' Dutch', ' French', ' Italian', ' Mandarin'],
#  ['English', ' Portuguese'],
#  ['English'],
#  ['English'],
#  ['English', ' Portuguese', ' French', ' Japanese'],
#  ['Korean'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['English', ' German', ' French'],
#  ['English'],
#  ['English', ' Ukrainian'],
#  ['English'],
#  ['Polish'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['Japanese'],
#  ['English'],
#  ['English', ' Cantonese'],
#  ['English'],
#  ['Dutch', ' English', ' Danish'],
#  ['English'],
#  ['English', ' German'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['Polish', ' German'],
#  ['Punjabi'],
#  ['English'],
#  ['Hindi'],
#  ['Tamil'],
#  ['Punjabi'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Hindi', ' English'],
#  ['Hindi'],
#  ['Punjabi'],
#  ['Hindi'],
#  ['Hindi'],
#  ['English'],
#  ['Punjabi'],
#  ['Punjabi'],
#  ['Marathi'],
#  ['English'],
#  ['Punjabi'],
#  ['Hindi', ' Urdu'],
#  ['Punjabi'],
#  ['Hindi', ' Marathi', ' Bengali', ' English', ' Portuguese'],
#  ['English'],
#  ['English'],
#  ['Punjabi'],
#  ['Hindi'],
#  ['Hindi'],
#  ['Hindi'],
#  ['Hindi', ' Urdu', ' English'],
#  ['Punjabi'],
#  ['Hindi'],
#  ['Hindi', ' English'],
#  ['Punjabi'],
#  ['Punjabi'],
#  ['English'],
#  ['Tamil'],
#  ['Tamil'],
#  ['Hindi', ' Marathi', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Tamil', ' Telugu'],
#  ['Hindi'],
#  ['Punjabi'],
#  ['Punjabi'],
#  ['Bengali'],
#  ['English'],
#  ['Tamil'],
#  ['Punjabi'],
#  ['English', ' German'],
#  ['Hindi'],
#  ['Punjabi'],
#  ['Punjabi'],
#  ['Hungarian'],
#  ['Tamil'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['Tamil'],
#  ['Hindi'],
#  ['Hindi'],
#  ['Punjabi'],
#  ['English'],
#  ['Urdu'],
#  ['Korean'],
#  ['French'],
#  ['Korean'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Portuguese'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['French'],
#  ['Italian', ' English', ' French'],
#  ['English', ' French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Japanese'],
#  ['English'],
#  ['English'],
#  ['French', ' English'],
#  ['French'],
#  ['French', ' English', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['Chinese'],
#  ['English', ' Mandarin'],
#  ['Norwegian', ' French', ' Swedish'],
#  ['Korean'],
#  ['Japanese'],
#  ['Spanish'],
#  ['Mandarin'],
#  ['Gujarati'],
#  ['Cantonese', ' English', ' Hokkien', ' Mandarin'],
#  ['Japanese'],
#  ['English'],
#  ['Portuguese'],
#  ['English'],
#  ['Mandarin'],
#  ['Mandarin'],
#  ['English'],
#  ['English'],
#  ['Mandarin'],
#  ['Spanish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['Italian'],
#  ['Mandarin'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' Portuguese', ' Swahili', ' French'],
#  ['German', ' English', ' Polish', ' Swedish'],
#  ['Chinese'],
#  ['English'],
#  ['English', ' French', ' Scottish Gaelic', ' Latin'],
#  ['Portuguese'],
#  ['Spanish'],
#  ['English'],
#  ['Icelandic'],
#  ['English'],
#  ['English'],
#  ['Telugu'],
#  ['English'],
#  ['French', ' Thai', ' English'],
#  ['English'],
#  ['Spanish'],
#  ['English', ' Japanese'],
#  ['English'],
#  ['Thai'],
#  ['Korean', ' Japanese', ' Mandarin', ' Russian', ' German', ' English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' French', ' Swahili'],
#  ['English'],
#  ['Japanese'],
#  ['Mandarin'],
#  ['English'],
#  ['English'],
#  ['French'],
#  ['Korean'],
#  ['English'],
#  ['Korean'],
#  ['Marathi'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['English'],
#  ['English', ' Nyanja', ' Afrikaans', ' Zulu', ' Xhosa', ' Southern Sotho'],
#  ['English'],
#  ['English'],
#  ['English', ' Hebrew', ' German', ' Ukrainian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Thai', ' Japanese', ' English'],
#  ['Hindi'],
#  ['Polish', ' English', ' Vietnamese', ' Russian', ' Chinese'],
#  ['English'],
#  ['English'],
#  ['English', ' French', ' Spanish'],
#  ['English'],
#  ['Spanish'],
#  ['Italian', ' English'],
#  ['English', ' French'],
#  ['French'],
#  ['Hindi', ' Urdu'],
#  ['Hindi'],
#  ['French', ' English', ' Spanish', ' Arabic'],
#  ['Spanish', ' English'],
#  ['Spanish'],
#  ['English', ' Russian'],
#  ['English'],
#  ['English'],
#  ['Wolof', ' French', ' English', ' Arabic'],
#  ['English'],
#  ['French'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Cantonese', ' Mandarin', ' English', ' Korean', ' French', ' Turkish'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Portuguese'],
#  ['English'],
#  ['French'],
#  ['English', ' French'],
#  ['English'],
#  ['English', ' German', ' Russian'],
#  ['Telugu'],
#  ['English'],
#  ['English', ' Italian', ' Latin', ' Spanish', ' German'],
#  ['English'],
#  ['English'],
#  ['Mandarin', ' Arabic', ' English'],
#  ['Hindi'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['Spanish'],
#  ['French'],
#  ['English'],
#  ['English'],
#  ['English', ' Japanese'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['English'],
#  ['Japanese'],
#  ['English'],
#  ['English', ' Spanish'],
#  ['English', ' French'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['English', ' Japanese', ' Italian', ' Spanish'],
#  ['English'],
#  ['English'],
#  ['Japanese'],
#  ['English'],
#  ['Portuguese'],
#  ['English'],
#  ['English'],
#  ['English', ' Spanish', ' French', ' Romanian'],
#  ['Korean'],
#  ['English'],
#  ['English'],
#  ['Hindi'],
#  ['English'],
#  ['English', ' Russian'],
#  ['French'],
#  ['English'],
#  ['English'],
#  ['Korean'],
#  ['Ukrainian Sign Language', ' Ukrainian'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['Spanish'],
#  ['English'],
#  ['Thai'],
#  ['English'],
#  ['English', ' Spanish', ' Hindi'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English'],
#  ['English', ' French', ' Spanish', ' Korean'],
#  ['German'],
#  ['English'],
#  ['English'],
#  ['Spanish', ' Tarahumara'],
#  ['English'],
#  ['Telugu'],
#  ['English', ' Italian'],
#  ['English', ' Ukrainian'],
#  ['English'],
#  ['English'],
#  ['English', ' German', ' Italian'],
#  ...]

# %%
# Loop through language (omdb language) and get unique values into language_set set
language_set = set()

for row in language:
    for i in row:
        language_set.add(i)
print(language_set)

language_df = pd.DataFrame(language_set, columns=["language"])
language_df = language_df.reset_index()
language_df = language_df.rename(columns={'index': 'language_no'})
language_df.head()
# Out:
# {' Berber languages', 'Serbo-Croatian', ' Nepali', 'Sanskrit', ' Xhosa', ' Kazakh', 'Hungarian', 'Tamil', ' Quechua', 'Indonesian', 'Malay', 'Hindi', 'Assamese', 'Wolof', 'Croatian', 'Yoruba', 'Akan', ' Filipino', 'Italian', 'Malayalam', ' Japanese', 'Ukrainian Sign Language', 'Georgian', ' Akan', ' Armenian', 'Gujarati', ' Kriolu', 'Latin', 'Hokkien', ' Italian', ' Somali', 'Khmer', ' Irish', 'Cantonese', ' Quenya', ' Dari', 'Dutch', ' Yoruba', ' Czech', ' Amharic', ' Washoe', 'Persian', ' Hungarian', ' Kurdish', ' Hindi', 'Neapolitan', 'Finnish', ' Bhojpuri', 'Bengali', ' Slovenian', ' Russian', ' Mongolian', ' Marathi', ' Japanese Sign Language', 'Korean', 'Catalan', 'Flemish', 'Pushto', ' Awadhi', 'Spanish', ' Hokkien', ' Estonian', ' Vietnamese', ' Danish', ' Ukrainian', ' Gujarati', ' Indonesian', ' Korean', ' Urdu', ' Manipuri', ' Egyptian (Ancient)', 'Romanian', ' Chechen', 'Polish', ' Indian Sign Language', ' Afrikaans', 'Urdu', ' Nama', ' Swiss German', 'Russian', ' Yiddish', ' Arabic', ' Maori', 'Chinese', ' Bable', ' Norwegian', 'Bhojpuri', ' Cree', 'Panjabi', ' Albanian', 'Serbian', ' Aboriginal', ' Burmese', ' Mandarin', ' Tajik', ' Polish', ' French', ' Old English', ' Sanskrit', ' Persian', ' Saami', ' Bengali', 'Punjabi', 'Telugu', ' Bosnian', 'French', ' German', ' Klingon', 'Swedish', 'Kannada', ' Pushto', ' Serbo-Croatian', ' Telugu', 'Nepali', ' American Sign Language', ' Bulgarian', 'German', 'Thai', ' Romany', ' Zulu', ' Tarahumara', 'Tagalog', 'Sinhalese', ' Sinhalese', 'Zulu', ' Cheyenne', ' Mixtec', ' Teochew', ' Sindarin', ' Polynesian', 'Kikuyu', 'Min Nan', 'Icelandic', ' East-Greenlandic', 'Afrikaans', 'Japanese', ' Assamese', 'Mandarin', 'None', ' Mende', 'Vietnamese', 'Khasi', ' Swedish', ' Lithuanian', ' Greek', 'Turkish', ' Syriac', 'Welsh', ' Punjabi', ' Assyrian Neo-Aramaic', ' Basque', 'Oriya', ' Serbian', ' Flemish', 'Norwegian', 'American Sign Language', ' Ewe', ' Thai', ' English', ' Tagalog', ' Swahili', 'Portuguese', ' Lingala', ' Scottish Gaelic', 'Marathi', ' Kannada', ' Latin', ' Portuguese', ' Mohawk', ' Spanish', ' British Sign Language', ' Ibo', ' Aragonese', 'Ukrainian', ' Central American Indian languages', ' Min Nan', ' Hawaiian', 'Hebrew', 'Slovenian', ' Cantonese', ' Turkmen', ' Khmer', ' Tamil', 'Filipino', 'Arabic', ' Finnish', ' Mapudungun', ' Uighur', ' Hebrew', ' Nyanja', 'English', ' Hausa', ' Icelandic', 'Shona', 'Basque', ' Greenlandic', ' Southern Sotho', ' Tibetan', ' Catalan', ' Wolof', 'Bulgarian', ' Romanian', ' Malayalam', ' Chinese', ' Dutch', ' Latvian', ' Minangkabau', ' Turkish', 'Danish', 'Greek', ' Croatian', ' Malay'}
#    language_no           language
# 0            0   Berber languages
# 1            1     Serbo-Croatian
# 2            2             Nepali
# 3            3           Sanskrit
# 4            4              Xhosa

# %%
# Break out languages with show_id
language_all_df = merged_df.loc[:,['show_id', 'language']]
language_all_df = language_all_df.explode('language')
language_all_df.dropna(inplace = True)
language_all_df.head()
# Out:
#     show_id language
# 0  81145628  English
# 1  80117401  English
# 1  80117401    Dutch
# 2  70234439  English
# 3  80058654  English

# %%
# merge tables to create show_id and language_no table
language_table = language_all_df.merge(language_df,how = "left", on="language")
language_table = language_table.loc[:,['show_id','language_no']]
language_table.head()
# Out:
#     show_id  language_no
# 0  81145628          190
# 1  80117401          190
# 2  80117401          204
# 3  70234439          190
# 4  80058654          190

# %%
title_df = merged_df.drop(columns=["listed_in","genre","language","Unnamed: 0"])
title_df_show = title_df.loc[title_df.show_id == 80057969]
title_df_show
# Out:
#      show_id   type title    director  \
# 19  80057969  Movie  Love  Gaspar Noé
#
#                                                  cast          country  \
# 19  Karl Glusman, Klara Kristin, Aomi Muyock, Ugo ...  France, Belgium
#
#            date_added  release_year rating duration  \
# 19  September 8, 2017          2015     NR  135 min
#
#                                           description  runtime  imdbRating  \
# 19  A man in an unsatisfying marriage recalls the ...  135 min         6.1
#
#     imdbVotes                                             poster  \
# 19      48168  https://m.media-amazon.com/images/M/MV5BMTQzND...
#
#                     awards boxoffice
# 19  2 wins & 1 nomination.  $249,083

# %% [markdown]
# ## Load data into postgres using sqlalchemy

# %%
# create connection to ETL_project_DB in postgres
# import psycopg2
engine = create_engine('postgresql://postgres:'+ password + '@localhost:5432/')
connection = engine.connect()

# %%
# check table names in database
engine.table_names()
# Out:
# ['OMDB_language',
#  'OMDB_title_language',
#  'OMDB_genre',
#  'OMDB_title_genre',
#  'Title',
#  'Netflix_Listed_in',
#  'Netflix_title_Listed_in']

# %%
# load dataframes into postgres using pandas
title_df.to_sql(name='Title', con=engine, if_exists='append', index=False)

netflix_genre_id.to_sql(name='Netflix_Listed_in', con=engine, if_exists='append', index=False)
netflix_genre_table.to_sql(name='Netflix_title_Listed_in', con=engine, if_exists='append', index=False)

omdb_genre_id.to_sql(name='OMDB_genre', con=engine, if_exists='append', index=False)
omdb_genre_table.to_sql(name='OMDB_title_genre', con=engine, if_exists='append', index=False)

language_df.to_sql(name='OMDB_language', con=engine, if_exists='append', index=False)
language_table.to_sql(name='OMDB_title_language', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-05ebd16739d6> in <module>
#       1 # load dataframes into postgres using pandas
# ----> 2 title_df.to_sql(name='Title', con=engine, if_exists='append', index=False)
#       3
#       4 netflix_genre_id.to_sql(name='Netflix_Listed_in', con=engine, if_exists='append', index=False)
#       5 netflix_genre_table.to_sql(name='Netflix_title_Listed_in', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
# -> 1478                 util.reraise(*exc_info)
#    1479
#    1480         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1224                 if not evt_handled:
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#    1228             elif not parameters and context.no_parameters:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ~\anaconda3\lib\encodings\utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:
