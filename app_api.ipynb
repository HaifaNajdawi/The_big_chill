# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from collections import OrderedDict
import pandas as pd

# %%
engine = create_engine(
    "postgres+psycopg2://{username}:{password}@netflix.cy8gt7mz64dd.us-east-2.rds.amazonaws.com:5432/postgres")
Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)
Base.classes.keys()
# Out:
# ['OMDB_genre', 'Title', 'Netflix_Listed_in', 'OMDB_language', 'cast']

# %%
titles=Base.classes.Title
titles
# Out:
# sqlalchemy.ext.automap.Title

# %%
title_sql=session.query(titles).all()

# %%
list=[]
for i in title_sql:
    feature_dict={}
    feature_dict["title"]=i.title
    feature_dict["rating"]=i.rating
    feature_dict["imdb_rating"]=i.imdbrating
    feature_dict["description"]=i.description
    feature_dict["type"]=i.type
    feature_dict["country"]=i.country
    feature_dict["poster"]=i.poster
    list.append(feature_dict)
title_dict={}
title_dict["netflix"]=list
title_dict
# Out:
# {'netflix': [{'title': 'Norm of the North: King Sized Adventure',
#    'rating': 'TV-PG',
#    'imdb_rating': 3.3,
#    'description': 'Before planning an awesome wedding for his grandfather, a polar bear king must take back a stolen artifact from an evil archaeologist first.',
#    'type': 'Movie',
#    'country': 'United States, India, South Korea, China',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNjMwZDhhZWYtOTM0OC00ZTQzLWIyNDktNDM1NmVkYTY4NWNlXkEyXkFqcGdeQXVyNTYyNDUxMDc@._V1_SX300.jpg'},
#   {'title': 'Jandino: Whatever it Takes',
#    'rating': 'TV-MA',
#    'imdb_rating': 4.8,
#    'description': 'Jandino Asporaat riffs on the challenges of raising kids and serenades the audience with a rousing rendition of "Sex on Fire" in his comedy show.',
#    'type': 'Movie',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMWE3MGVjZDktODE1YS00ZTg0LThkMDItYWMwZjE3OTI2YWQwXkEyXkFqcGdeQXVyNDY1ODY3Mw@@._V1_SX300.jpg'},
#   {'title': 'Transformers Prime',
#    'rating': 'TV-Y7-FV',
#    'imdb_rating': 7.9,
#    'description': 'With the help of three human allies, the Autobots once again protect Earth from the onslaught of the Decepticons and their leader, Megatron.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTczNDM3MzY1Nl5BMl5BanBnXkFtZTcwOTg5NjU1OQ@@._V1_SX300.jpg'},
#   {'title': 'Transformers: Robots in Disguise',
#    'rating': 'TV-Y7',
#    'imdb_rating': 6.0,
#    'description': 'When a prison ship crash unleashes hundreds of Decepticons on Earth, Bumblebee leads a new Autobot force to protect humankind.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjMwNTIxNzEwMV5BMl5BanBnXkFtZTgwNDMwMDI1NTE@._V1_SX300.jpg'},
#   {'title': '#realityhigh',
#    'rating': 'TV-14',
#    'imdb_rating': None,
#    'description': 'When nerdy high schooler Dani finally attracts the interest of her longtime crush, she lands in the cross hairs of his ex, a social media celebrity.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': None},
#   {'title': 'Apaches',
#    'rating': 'TV-MA',
#    'imdb_rating': 5.9,
#    'description': 'A young journalist is forced into a life of crime to save his father and family in this series based on the novel by Miguel Sáez Carral.',
#    'type': 'TV Show',
#    'country': 'Spain',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BODYyOTQ2MTA0NF5BMl5BanBnXkFtZTgwOTgzNjgwOTE@._V1_SX300.jpg'},
#   {'title': 'Automata',
#    'rating': 'R',
#    'imdb_rating': 6.1,
#    'description': 'In a dystopian future, an insurance adjuster for a tech company investigates a robot killed for violating protocol and discovers a global conspiracy.',
#    'type': 'Movie',
#    'country': 'Bulgaria, United States, Spain, Canada',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNzgyMDcyMjMwMV5BMl5BanBnXkFtZTgwNjY5MTA1MjE@._V1_SX300.jpg'},
#   {'title': 'Fabrizio Copano: Solo pienso en mi',
#    'rating': 'TV-MA',
#    'imdb_rating': 4.7,
#    'description': 'Fabrizio Copano takes audience participation to the next level in this stand-up set while reflecting on sperm banks, family WhatsApp groups and more.',
#    'type': 'Movie',
#    'country': 'Chile',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BN2E2OGEzYWMtOTdiNC00ZjVlLWFmNTYtNjJlNjA4MTZkOWM3XkEyXkFqcGdeQXVyMzUzNzM3MTA@._V1_SX300.jpg'},
#   {'title': 'Fire Chasers',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.6,
#    'description': "As California's 2016 fire season rages, brave backcountry firefighters race to put out the flames, protect homes and save lives in this docuseries.",
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNmQwZWQ0OWYtMDEyOS00NjQ3LWEwY2YtNjZkOWVmOWJlY2YzXkEyXkFqcGdeQXVyMjY0OTI5NTM@._V1_SX300.jpg'},
#   {'title': 'Good People',
#    'rating': 'R',
#    'imdb_rating': 5.5,
#    'description': "A struggling couple can't believe their luck when they find a stash of money in the apartment of a neighbor who was recently murdered.",
#    'type': 'Movie',
#    'country': 'United States, United Kingdom, Denmark, Sweden',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxOTk5ODc0Nl5BMl5BanBnXkFtZTgwNDA3MzExMjE@._V1_SX300.jpg'},
#   {'title': 'Joaquín Reyes: Una y no más',
#    'rating': 'TV-MA',
#    'imdb_rating': None,
#    'description': 'Comedian and celebrity impersonator Joaquín Reyes decides to be his zesty self for a night of stories about buses, bathroom habits, royalty and more.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Kidnapping Mr. Heineken',
#    'rating': 'R',
#    'imdb_rating': 6.1,
#    'description': 'When beer magnate Alfred "Freddy" Heineken is kidnapped in 1983, his abductors make the largest ransom demand in history.',
#    'type': 'Movie',
#    'country': 'Netherlands, Belgium, United Kingdom, United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTYyOTQwODc4NV5BMl5BanBnXkFtZTgwMDgwMzkxNDE@._V1_SX300.jpg'},
#   {'title': 'Krish Trish and Baltiboy',
#    'rating': 'TV-Y7',
#    'imdb_rating': 4.1,
#    'description': 'A team of minstrels, including a monkey, cat and donkey, narrate folktales from the Indian regions of Rajasthan, Kerala and Punjab.',
#    'type': 'Movie',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYjlhYTJhODctZGY4Zi00NjQ0LTkyYzAtNDkwYmNlY2IwZTZlXkEyXkFqcGdeQXVyNTM3NDk5MTg@._V1_SX300.jpg'},
#   {'title': 'Krish Trish and Baltiboy: Battle of Wits',
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': 'An artisan is cheated of his payment, a lion of his throne and a brother of his inheritance in these three stories of deception and justice.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Krish Trish and Baltiboy: Best Friends Forever',
#    'rating': 'TV-Y',
#    'imdb_rating': None,
#    'description': 'A cat, monkey and donkey team up to narrate folktales about friendship from Northeast India, and the Indian regions of Bihar and Rajasthan.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Krish Trish and Baltiboy: Comics of India',
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': 'In three comic-strip-style tales, a boy tries to sell wisdom, a demon is released from captivity, and a king assigns impossible tasks to his minister.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Krish Trish and Baltiboy: Oversmartness Never Pays',
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': 'A cat, monkey and donkey learn the consequences of cheating through stories from the Indian regions of Rajasthan, West Bengal and Maharashtra.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Krish Trish and Baltiboy: Part II',
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': "Animal minstrels narrate stories about a monkey's friendship with a crocodile, two monkeys' foolishness and a villager's encounter with a demon.",
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Krish Trish and Baltiboy: The Greatest Trick',
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': 'The consequences of trickery are explored in stories involving an inconsiderate husband, two greedy courtiers, and a kind man who loses everything.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Love',
#    'rating': 'NR',
#    'imdb_rating': 6.1,
#    'description': 'A man in an unsatisfying marriage recalls the details of an intense past relationship with an ex-girlfriend when he gets word that she may be missing.',
#    'type': 'Movie',
#    'country': 'France, Belgium',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNDUwODk5NF5BMl5BanBnXkFtZTgwNzA0MDQ2NTE@._V1_SX300.jpg'},
#   {'title': 'Manhattan Romance',
#    'rating': 'TV-14',
#    'imdb_rating': 5.6,
#    'description': 'A filmmaker working on a documentary about love in modern Manhattan becomes personally entangled in the romantic lives of his subjects.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODk2MDc0MF5BMl5BanBnXkFtZTgwMTc3NjU4NjE@._V1_SX300.jpg'},
#   {'title': 'Moonwalkers',
#    'rating': 'R',
#    'imdb_rating': 6.1,
#    'description': 'A brain-addled war vet, a failing band manager and a Stanley Kubrick impersonator help the CIA construct an epic scam by faking the 1969 moon landing.',
#    'type': 'Movie',
#    'country': 'France, Belgium',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjQyNzU4MjMyNF5BMl5BanBnXkFtZTgwMDQ0NzQ0NzE@._V1_SX300.jpg'},
#   {'title': 'Rolling Papers',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.2,
#    'description': 'As the newspaper industry takes a hit, The Denver Post breaks new ground with a section dedicated to cannabis culture.',
#    'type': 'Movie',
#    'country': 'United States, Uruguay',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4MjYwODUzN15BMl5BanBnXkFtZTgwMDIxNzMzNzE@._V1_SX300.jpg'},
#   {'title': 'Stonehearst Asylum',
#    'rating': 'PG-13',
#    'imdb_rating': 6.8,
#    'description': "In 1899, a young doctor arrives at an asylum for an apprenticeship and becomes suspicious of his mentor's methods while falling for a female patient.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNjg5NjU0MTM4N15BMl5BanBnXkFtZTgwMjU1NDQzMjE@._V1_SX300.jpg'},
#   {'title': 'The Runner',
#    'rating': 'R',
#    'imdb_rating': 4.7,
#    'description': 'A New Orleans politician finds his idealistic plans for rebuilding after a toxic oil spill unraveling thanks to a sex scandal.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTkyMDkwNDIyMV5BMl5BanBnXkFtZTgwNDU1OTEwNjE@._V1_SX300.jpg'},
#   {'title': '6 Years',
#    'rating': 'NR',
#    'imdb_rating': 5.6,
#    'description': 'As a volatile young couple who have been together for six years approach college graduation, unexpected career opportunities threaten their future.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTYzMTMwMDMzMF5BMl5BanBnXkFtZTgwNDc4MjUzNjE@._V1_SX300.jpg'},
#   {'title': 'Castle of Stars',
#    'rating': 'TV-14',
#    'imdb_rating': None,
#    'description': 'As four couples with different lifestyles go through the ebbs and flows of joy and sorrow, each must learn how to live a good life.',
#    'type': 'TV Show',
#    'country': None,
#    'poster': None},
#   {'title': 'City of Joy',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.5,
#    'description': "Women who've been sexually brutalized in war-torn Congo begin to heal at City of Joy, a center that helps them regain a sense of self and empowerment.",
#    'type': 'Movie',
#    'country': 'United States,',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNGUwMDA5ZmQtNzQ2Zi00ZTUzLWFhZDctYjc2ZGU5ODM4ZjU5XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg'},
#   {'title': 'First and Last',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.8,
#    'description': "Take an intimate look at the emotionally charged first and last days of new and soon-to-be released inmates at Georgia's Gwinnett County Jail.",
#    'type': 'TV Show',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYTQ0MDA4YzctYmRjNy00MTIzLWI3MzItN2RjYmE3YWFhZWI4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'Laddaland',
#    'rating': 'TV-MA',
#    'imdb_rating': None,
#    'description': 'When a family moves into an upscale housing development, they encounter a series of paranormal events that drive them to the edge of insanity.',
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': None},
#   {'title': 'Next Gen',
#    'rating': 'TV-PG',
#    'imdb_rating': 6.6,
#    'description': 'When lonely Mai forms an unlikely bond with a top-secret robot, they embark on an intense, action-packed adventure to foil the plot of a vicious villain.',
#    'type': 'Movie',
#    'country': 'China, Canada, United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTU0MjAwMDkxNV5BMl5BanBnXkFtZTgwMTA4ODIxNjM@._V1_SX300.jpg'},
#   {'title': 'Sierra Burgess Is A Loser',
#    'rating': 'PG-13',
#    'imdb_rating': 5.8,
#    'description': "A wrong-number text sparks a virtual romance between a smart but unpopular teen and a sweet jock who thinks he's talking to a gorgeous cheerleader.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTU5Mjc4NTM2Ml5BMl5BanBnXkFtZTgwMjMzMzA5NTM@._V1_SX300.jpg'},
#   {'title': 'The Most Assassinated Woman in the World',
#    'rating': 'TV-MA',
#    'imdb_rating': 5.3,
#    'description': 'In 1930s Paris, an actress famous for her gory death scenes at the Grand Guignol Theater contends with a mysterious stalker and ghosts from her past.',
#    'type': 'Movie',
#    'country': 'Belgium, United Kingdom, United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzBhOGY1N2QtMTVhYi00YzgzLTlmODctM2JmNmIxOWY2ZDM4XkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SX300.jpg'},
#   {'title': 'Cézanne et moi',
#    'rating': 'R',
#    'imdb_rating': 6.0,
#    'description': 'This historical drama explores the long and often volatile friendship of painter Paul Cézanne and writer Émile Zola, who first met as schoolboys.',
#    'type': 'Movie',
#    'country': 'Belgium, France',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYzVlYmE1ZTUtMDZkNC00YTQ2LTg1YjgtYmUzNzE0ZDFlMmE5XkEyXkFqcGdeQXVyMTY5Nzc4MDY@._V1_SX300.jpg'},
#   {'title': "Archibald's Next Big Thing",
#    'rating': 'TV-Y7',
#    'imdb_rating': 7.9,
#    'description': "Happy-go-lucky chicken Archibald may not remember to do his chores, but he never forgets to have fun. After all, life's an adventure!",
#    'type': 'TV Show',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOTI0YzkxY2ItNmRkYS00YTliLTg2YTUtN2UxMzQ4YWJiNzNmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'Article 15',
#    'rating': 'TV-MA',
#    'imdb_rating': 8.2,
#    'description': 'The grim realities of caste discrimination come to light as an entitled but upright city cop ventures into India’s heartland to investigate a murder.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZTI2NTFiMDMtZjQxNS00YjBkLWFhNWMtOTIyMzE5Yjc0ZTZiXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg'},
#   {'title': 'Care of Kancharapalem',
#    'rating': 'TV-14',
#    'imdb_rating': None,
#    'description': 'From a schoolboy’s crush to a middle-aged bachelor’s office romance, four love stories spanning age, religion and status unfold in a small Indian town.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Ee Nagaraniki Emaindi',
#    'rating': 'TV-14',
#    'imdb_rating': 7.9,
#    'description': 'In Goa and in desperate need of cash, four childhood friends get another shot at making their long-abandoned dreams of becoming filmmakers come true.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNGE4MDIwMDAtNzViZC00NWJlLWEwNjYtZmUwZDE2ZTRlYTY3XkEyXkFqcGdeQXVyNTgxODY5ODI@._V1_SX300.jpg'},
#   {'title': 'Kill Me If You Dare',
#    'rating': 'TV-14',
#    'imdb_rating': None,
#    'description': 'Bogged down with money problems, a couple grows cautious of each other but hit the lottery and decide to stay together – till death do they part.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'The Spy',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.9,
#    'description': 'In the 1960s, Israeli clerk-turned-secret agent Eli Cohen goes deep undercover inside Syria on a perilous, years-long mission to spy for Mossad.',
#    'type': 'TV Show',
#    'country': 'France',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BM2ZmYjUxZDYtMmZlMi00YjlkLTkwNTItMjcxZDRlOTI3ZTNmXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg'},
#   {'title': 'Hell and Back',
#    'rating': 'R',
#    'imdb_rating': 5.4,
#    'description': 'When best friends break a blood oath, one of them is cast away to hell, and the other two must save him from the misfits of the underworld.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjM4NzUxODgyNV5BMl5BanBnXkFtZTgwMDM5MzA3NjE@._V1_SX300.jpg'},
#   {'title': 'PK',
#    'rating': 'TV-14',
#    'imdb_rating': 8.1,
#    'description': 'Aamir Khan teams with director Rajkumar Hirani to play a social crusader in a political satire on the state of corruption in India.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTYzOTE2NjkxN15BMl5BanBnXkFtZTgwMDgzMTg0MzE@._V1_SX300.jpg'},
#   {'title': 'Hard Tide',
#    'rating': 'TV-MA',
#    'imdb_rating': 4.9,
#    'description': "A drug dealer who's been emulating his father's successful criminal career is forced to go on the run with a young girl in this fact-based thriller.",
#    'type': 'Movie',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMmU3N2NjMjAtOTY5NC00ZWQ1LWI1ZTMtZjBlNzk2NGVmMTU0XkEyXkFqcGdeQXVyMTk3OTA5Mzk@._V1_SX300.jpg'},
#   {'title': 'Elstree 1976',
#    'rating': 'TV-PG',
#    'imdb_rating': 5.9,
#    'description': 'Then and now footage of bit players who appeared in "Star Wars" tells the story of how the film and its legions of fans changed their lives forever.',
#    'type': 'Movie',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjQ0MDk4MDc1NV5BMl5BanBnXkFtZTgwNzk4OTQxNzE@._V1_SX300.jpg'},
#   {'title': 'American Factory: A Conversation with the Obamas',
#    'rating': 'TV-G',
#    'imdb_rating': 5.2,
#    'description': 'Barack and Michelle Obama talk with directors Steven Bognar and Julia Reichert about the documentary and the importance of storytelling.',
#    'type': 'Movie',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMmNjZWQzOTAtNGVhMC00ZTQ2LTllNmMtYmEyY2ZiM2MyMDQzXkEyXkFqcGdeQXVyMTcyMDgxNQ@@._V1_SX300.jpg'},
#   {'title': 'ATM',
#    'rating': 'TV-14',
#    'imdb_rating': 4.7,
#    'description': 'When a broken ATM dishes out a fortune, a couple who works at the bank vies to see who can recover the most cash – and the loser must find a new job.',
#    'type': 'Movie',
#    'country': 'United States, Canada',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4OTQxMzU5OV5BMl5BanBnXkFtZTcwNDMyNzM0Nw@@._V1_SX300.jpg'},
#   {'title': 'Bangkok Traffic (Love) Story',
#    'rating': 'TV-14',
#    'imdb_rating': 7.2,
#    'description': 'After an encounter with an engineer working the night shift for the city train, a 30-year-old woman struggles against all odds to pursue true love.',
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMWExZGMyYjctNzM2NC00MTM3LThlODktNzY5OWI4YzI4YmJlXkEyXkFqcGdeQXVyNDc5MzE4NjQ@._V1_SX300.jpg'},
#   {'title': 'I Fine... Thank You... Love You',
#    'rating': 'TV-14',
#    'imdb_rating': 7.0,
#    'description': "Desperate to go to the U.S. to win back his girlfriend, Yim hires a tutor to teach him English. But things don't go according to plan.",
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZjVlMWY0ZTUtODIxMC00MmRhLTlkMmMtZGU4MjhmZGY3NGJiXkEyXkFqcGdeQXVyNzI1NzMxNzM@._V1_SX300.jpg'},
#   {'title': 'One Day',
#    'rating': 'TV-PG',
#    'imdb_rating': 7.0,
#    'description': 'When his colleague (and crush) temporarily loses her memory, an overlooked geek seizes the chance to make an impression before she remembers again.',
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3NTg2MDI3NF5BMl5BanBnXkFtZTcwMjc5MTA1NA@@._V1_SX300.jpg'},
#   {'title': 'Phobia 2',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.7,
#    'description': 'From disfiguring punishments to festering souls, Thai horror masters present five supernatural tales of karma in this sequel to the 4bia anthology.',
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjNjMjZkMmQtY2ZmYi00ZjNmLWIxYWUtMWI0NTAzNWEyNzE1XkEyXkFqcGdeQXVyNjAzNDg0MzY@._V1_SX300.jpg'},
#   {'title': 'Shutter',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.1,
#    'description': 'After killing a young girl in a hit-and-run accident, a couple is haunted by more than just the memory of their deadly choice.',
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNGY1MDdhZmItNTlhOS00N2ZlLTgxY2MtMDJkZTAzYTc0NDllXkEyXkFqcGdeQXVyNTk5MjI2NzQ@._V1_SX300.jpg'},
#   {'title': 'Suckseed',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.5,
#    'description': 'When his boyhood crush Ern returns, Ped forms a band with his friend to impress her. Romantic rivalries bloom after the talented Ern joins the group.',
#    'type': 'Movie',
#    'country': 'Thailand',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYTEwZTdjNmYtOWI4Ni00YThhLTk3ZGEtYjJhYTEyOWY4MTY2XkEyXkFqcGdeQXVyNzI1NzMxNzM@._V1_SX300.jpg'},
#   {'title': 'Carrie Pilby',
#    'rating': 'TV-14',
#    'imdb_rating': 6.7,
#    'description': 'A socially awkward 19-year-old genius makes big plans to step out of her shell and make a friend, get a job and – maybe – even go on a date.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjMxMTQ2ODgwMF5BMl5BanBnXkFtZTgwNjQyODY2MTI@._V1_SX300.jpg'},
#   {'title': 'Marc Maron: Too Real',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.2,
#    'description': 'Battle-scarred stand-up comedian Marc Maron unleashes a storm of ideas about meditation, mortality, documentary films and our weird modern world.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNjFiMzU5OTMtMmYyMC00OWMxLTk0NTktNzA0MTY0YjkwNTFjXkEyXkFqcGdeQXVyNjc0NzYyMzI@._V1_SX300.jpg'},
#   {'title': 'No Tomorrow',
#    'rating': 'TV-14',
#    'imdb_rating': 7.3,
#    'description': 'Her straitjacketed life turned topsy-turvy by hunky Xavier, Evie discovers a new freedom – even though her man just might be an end-of-days crackpot.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTc2ODUwNjgyMF5BMl5BanBnXkFtZTgwNTE0NDg4OTE@._V1_SX300.jpg'},
#   {'title': 'Saawan',
#    'rating': 'TV-14',
#    'imdb_rating': 6.9,
#    'description': 'Outcast from society and left to die in the wilderness, a young boy with polio embarks on a journey to connect with his mother. Based on a true story.',
#    'type': 'Movie',
#    'country': 'Pakistan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BN2FhODQ1ODUtMzk0Zi00NDRkLWFmMmQtOGQzZDM0YmUwYjBmXkEyXkFqcGdeQXVyMTcwNDk2NjE@._V1_SX300.jpg'},
#   {'title': 'The Heretics',
#    'rating': 'TV-MA',
#    'imdb_rating': 4.7,
#    'description': 'A withdrawn young woman hunted by a malicious cult is abducted by a brooding stranger and undergoes a bizarre transformation.',
#    'type': 'Movie',
#    'country': 'Canada',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BY2Y1YjE5YzQtOTVmOS00N2RlLWI0ODktYzRiZmU1OGE2YjA3L2ltYWdlXkEyXkFqcGdeQXVyMjc1NDU5MjU@._V1_SX300.jpg'},
#   {'title': 'The World We Make',
#    'rating': 'PG',
#    'imdb_rating': 5.3,
#    'description': 'A teenage equestrian and a local football player for each other, but simmering racism in their small town puts their relationship to the test.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNzAzZDM3MTgtNDFhZS00OWY5LTk2ZDUtYzk1NDQ5MWFkYjAwXkEyXkFqcGdeQXVyODUwNjMwOQ@@._V1_SX300.jpg'},
#   {'title': 'Watchman',
#    'rating': 'TV-14',
#    'imdb_rating': 5.3,
#    'description': 'Rushing to pay off a loan shark, a young man breaks into a bungalow to steal the cash, unprepared for the dog standing guard – or the trouble inside.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNGZhNmU3YzYtYThkNy00NzRhLWJiYjMtY2E3N2ZhNjBjZmI0XkEyXkFqcGdeQXVyOTk3NTc2MzE@._V1_SX300.jpg'},
#   {'title': 'Black Panther',
#    'rating': 'PG-13',
#    'imdb_rating': 7.3,
#    'description': "T'Challa, the superpowered new leader of the hidden, highly advanced African nation of Wakanda, strives to protect his home from enemies old and new.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SX300.jpg'},
#   {'title': 'Man Up',
#    'rating': 'R',
#    'imdb_rating': 6.8,
#    'description': 'A single woman seizes an opportunity when, while standing under a train station clock, she meets a stranger who mistakes her for his blind date.',
#    'type': 'Movie',
#    'country': 'United Kingdom, France',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTUzODcxNDcxMl5BMl5BanBnXkFtZTgwODE1NjM4NTE@._V1_SX300.jpg'},
#   {'title': 'Frequency',
#    'rating': 'TV-14',
#    'imdb_rating': 7.3,
#    'description': 'A detective seizes a precious opportunity to change the past when she finds she can communicate with her deceased, estranged father via a time warp.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTI4NTgyOTIxN15BMl5BanBnXkFtZTYwMTUwODY3._V1_SX300.jpg'},
#   {'title': 'Mo Gilligan: Momentum',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.3,
#    'description': 'Comedian Mo Gilligan blends smooth moves and sharp humor as he riffs on humble beginnings, family dynamics and the complex art of dancing in the club.',
#    'type': 'Movie',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOTUwMDIzOTEtNTY4YS00MDY4LTg5NDgtYzI4ZmZmOTEyM2RjXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'Adam Ruins Everything',
#    'rating': 'TV-14',
#    'imdb_rating': 8.0,
#    'description': 'Education can be fun – and funny. Comedian Adam Conover bursts misconceptions, deconstructs topics and leaves with positive takeaways.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTEyNzQyNzQyNjJeQTJeQWpwZ15BbWU4MDEwMjIyOTYx._V1_SX300.jpg'},
#   {'title': 'Ben 10',
#    'rating': 'TV-Y7',
#    'imdb_rating': 7.2,
#    'description': "Ben can transform into ten types of aliens. He'll try 'em all while adventuring across the country with his cousin Gwen and Grandpa Max.",
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMGU1MGQ1YTgtZTdkYi00ODI3LWFjMzItYmZkN2IxMmM0M2M4XkEyXkFqcGdeQXVyOTgwMzk1MTA@._V1_SX300.jpg'},
#   {'title': 'Big Miracle',
#    'rating': 'PG',
#    'imdb_rating': 6.5,
#    'description': 'After a reporter writes about whales trapped in the Arctic Circle, the U.S. and U.S.S.R. team up to rescue them in this tale inspired by true events.',
#    'type': 'Movie',
#    'country': 'United States, United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjEzNTg5MjA5NV5BMl5BanBnXkFtZTcwNjk0MTk5Ng@@._V1_SX300.jpg'},
#   {'title': 'Christiane Amanpour: Sex & Love Around the World',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.4,
#    'description': "A contextual, acculturated dive into how adults in six, big global cities celebrate love and accentuate sex. CNN's Christiane Amanpour reports.",
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOTI1ZjAyMGQtZmEwOC00ZTYzLThmZTEtZjg3NGFiYzg4MWUwXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'The Eighties',
#    'rating': 'TV-PG',
#    'imdb_rating': 8.3,
#    'description': 'This nostalgic documentary series relives the 1980s from a variety of angles, exploring its impact on the politics, technology and culture of today.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNTI5MTQ3NTc0MF5BMl5BanBnXkFtZTgwMjE2NDI0ODE@._V1_SX300.jpg'},
#   {'title': 'The Nineties',
#    'rating': 'TV-14',
#    'imdb_rating': 8.2,
#    'description': 'This U.S.-focused series dives into the cultural and political changes that swept the last decade of the 20th century. Executive produced by Tom Hanks.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZDlhY2JkYzQtMTcwMy00YjljLTk4MmQtYzg5NzUyZGYyYjgzXkEyXkFqcGdeQXVyODQ1NTk5OQ@@._V1_SX300.jpg'},
#   {'title': 'The Seventies',
#    'rating': 'TV-PG',
#    'imdb_rating': 8.3,
#    'description': 'This series examines 1970s America, focusing on the major political and historical landmarks of the decade and the cultural response to those events.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTYwNzI0NTA4NV5BMl5BanBnXkFtZTgwMzI5MzM5NTE@._V1_SX300.jpg'},
#   {'title': 'We Bare Bears',
#    'rating': 'TV-Y7',
#    'imdb_rating': 7.9,
#    'description': 'Grizzly, Panda and Ice Bear are three adopted bear brothers struggling against their animal instincts to fit into the civilized, modern human world.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYjQzOTA4N2YtYTlkMS00OTJlLWJiYTEtMDcxNWQ1NTNhYzYxXkEyXkFqcGdeQXVyNjM2NDIwMzQ@._V1_SX300.jpg'},
#   {'title': 'The Mayor',
#    'rating': 'TV-MA',
#    'imdb_rating': 5.6,
#    'description': 'With the presidency in mind, the incumbent mayor of Seoul runs for an unprecedented third term – and will stop at nothing to keep his secrets hidden.',
#    'type': 'Movie',
#    'country': 'South Korea',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNzA3YjQ2ZmYtMjY0Ni00NWRkLWIwYzgtZThkMWNmZWE4ZTYxXkEyXkFqcGdeQXVyMzAzNTY3MDM@._V1_SX300.jpg'},
#   {'title': 'The Royal House of Windsor',
#    'rating': 'TV-14',
#    'imdb_rating': 7.4,
#    'description': 'Drawing on newly available info, this show traces how the British royal family has survived the last 100 years of power struggles, politics and more.',
#    'type': 'TV Show',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjAzNDBmOGItZmUyYS00Y2Y0LThkMjMtYTk2YTNlYzk2NmExXkEyXkFqcGdeQXVyNTg3OTIzNTk@._V1_SX300.jpg'},
#   {'title': 'Amanda Knox',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.9,
#    'description': 'She was twice convicted and acquitted of murder. Amanda Knox and the people closest to her case speak out in this illuminating documentary.',
#    'type': 'Movie',
#    'country': 'Denmark, United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNTY5NjE4MTQyNF5BMl5BanBnXkFtZTgwMzg1NjEwMDI@._V1_SX300.jpg'},
#   {'title': 'Lovesick',
#    'rating': 'TV-14',
#    'imdb_rating': 8.1,
#    'description': 'Love and academics get complicated at an all-male college that happens to be located next to an all-female high school.',
#    'type': 'TV Show',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzdjNDU5ZTEtNTA3OC00MmZkLTk0MDAtNDM1OTg3Y2NmZGM1XkEyXkFqcGdeQXVyMjA4Njg4OTQ@._V1_SX300.jpg'},
#   {'title': 'The Debt Collector',
#    'rating': 'TV-MA',
#    'imdb_rating': 5.8,
#    'description': 'A broke martial arts instructor takes a side gig with a mobster, who pairs him with a veteran thug for a weekend of fisticuffs-fueled debt collection.',
#    'type': 'Movie',
#    'country': 'United Kingdom, United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYjViN2ZhOTktNDUyOS00MWE1LWI3MzEtMzNlOWFlYjc5ZDRkXkEyXkFqcGdeQXVyNzIzMTc2Mw@@._V1_SX300.jpg'},
#   {'title': 'Act of Vengeance',
#    'rating': 'NR',
#    'imdb_rating': 5.5,
#    'description': 'Two Turkish agents are sent to New York City on a mission to capture a notorious terrorist known only as "Dejjal" (Arabic for Antichrist).',
#    'type': 'Movie',
#    'country': 'Turkey, United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYjUxMmFjZjItMGM5YS00NGZkLTg2MTMtNDlhZjI4ZmNkZjFjXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SX300.jpg'},
#   {'title': 'Paradise Lost',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.0,
#    'description': 'A cop moonlights as the bodyguard for a young drag queen at a nightclub, and grows closer to the family of misfit singers that perform there.',
#    'type': 'Movie',
#    'country': 'Brazil',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZDVkOGViM2YtYmQ3Mi00MmJjLWE2ZTQtZGU5MmE3OTc3YzFmXkEyXkFqcGdeQXVyMTk5MTg0MjM@._V1_SX300.jpg'},
#   {'title': "Gerald's Game",
#    'rating': 'TV-MA',
#    'imdb_rating': 6.6,
#    'description': "When her husband's sex game goes wrong, Jessie – handcuffed to a bed in a remote lake house – faces warped visions, dark secrets and a dire choice.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzg0NGE0N2MtYTg1My00NTBkLWI5NjEtZTgyMDA0MTU4MmIyXkEyXkFqcGdeQXVyMTU2NTcyMg@@._V1_SX300.jpg'},
#   {'title': 'Long Shot',
#    'rating': 'TV-14',
#    'imdb_rating': 6.8,
#    'description': "When Juan Catalan is arrested for a murder he didn't commit, he builds his case for innocence around raw footage from a popular TV show. A documentary.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMmE4Mzk0OWQtMDI1OS00NDU3LWI2M2YtNzc1MGMxZGI3ZTE1XkEyXkFqcGdeQXVyMjMxOTE0ODA@._V1_SX300.jpg'},
#   {'title': 'Mak Cun',
#    'rating': 'TV-PG',
#    'imdb_rating': None,
#    'description': 'A woman with an entrepreneurial spirit takes life into her own hands by starting a beauty cream business that inspires other women to take chances.',
#    'type': 'TV Show',
#    'country': None,
#    'poster': None},
#   {'title': 'Our Souls at Night',
#    'rating': 'TV-14',
#    'imdb_rating': 6.9,
#    'description': 'After widowed neighbors Addie and Louis begin sleeping in bed together platonically to alleviate their loneliness, a real romance begins to blossom.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzU4ODQ5MDc5OV5BMl5BanBnXkFtZTgwMjk4MDM1MzI@._V1_SX300.jpg'},
#   {'title': 'Out of Thin Air',
#    'rating': 'TV-14',
#    'imdb_rating': 6.3,
#    'description': 'Picking up 40 years after six were convicted for two strange murders in Iceland, this chilling documentary proves confessions can’t always be trusted.',
#    'type': 'Movie',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNzk4NDUxNzktY2QzMC00MmFmLWFjMGUtNTMxMjdiMGM0MzE0XkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SX300.jpg'},
#   {'title': "Paul Hollywood's Big Continental Road Trip",
#    'rating': 'TV-14',
#    'imdb_rating': 7.5,
#    'description': 'Gear up for a fast-paced journey as celebrity chef and avid auto enthusiast Paul Hollywood takes in the cars and culture of France, Italy and Germany.',
#    'type': 'TV Show',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzk5NDRlMzAtOGU2MC00MzcyLTk5M2UtZDg3NzEzMDIzY2ZjXkEyXkFqcGdeQXVyMzQ0NDY1MDU@._V1_SX300.jpg'},
#   {'title': 'Satu Hari',
#    'rating': 'TV-14',
#    'imdb_rating': 6.3,
#    'description': "A man haunted by his wife's affair moves to Sarajevo and starts to love again, until fate forces him to choose between his new life and old loyalty.",
#    'type': 'TV Show',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMDU4OGVmOGYtMGFkNi00MzczLTg3NWYtZjRhYjE1NTExZDAyXkEyXkFqcGdeQXVyNzkzODk2Mzc@._V1_SX300.jpg'},
#   {'title': 'Monster High: Boo York, Boo York',
#    'rating': 'TV-Y7',
#    'imdb_rating': 6.5,
#    'description': 'Cleo is invited to a gala in the big city celebrating a magical comet and brings her best friends along. But the sinister Nefera has other plans.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MDU3MTczOF5BMl5BanBnXkFtZTgwNTYxNDA5NjE@._V1_SX300.jpg'},
#   {'title': 'Cultivating the Seas: History and Future of the Full-Cycle Cultured Kindai Tuna',
#    'rating': 'TV-G',
#    'imdb_rating': None,
#    'description': 'An in-depth look at the full-cycle breeding program for bluefin Kindai tuna pioneered by Kinki University’s Aqua Culture Research Institute.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Domino',
#    'rating': 'R',
#    'imdb_rating': 5.9,
#    'description': 'A Copenhagen police officer hunts for the man who attacked his partner, only to stumble into a high-stakes game of espionage.',
#    'type': 'Movie',
#    'country': 'Denmark, France, Italy, Belgium, Netherlands',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTkwOTA5Njc4Ml5BMl5BanBnXkFtZTcwNzg0MzEzMQ@@._V1_SX300.jpg'},
#   {'title': 'TUNA GIRL',
#    'rating': 'TV-PG',
#    'imdb_rating': 5.4,
#    'description': "A clumsy but cheerful fisheries student struggles to find her place at a research institute renowned for its tuna cultivation. The work isn't easy.",
#    'type': 'Movie',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOTcwMDgzODUtZTAzNy00YTFmLTlmMDYtZjg0Y2E2Yzg1NmMwXkEyXkFqcGdeQXVyNzA3ODUyNzY@._V1_SX300.jpg'},
#   {'title': '5CM',
#    'rating': 'TV-14',
#    'imdb_rating': None,
#    'description': 'Five friends embark on a mission to climb the highest peak in Java, overcoming obstacles on the way and discovering the true meaning of friendship.',
#    'type': 'Movie',
#    'country': 'Indonesia',
#    'poster': None},
#   {'title': 'Animal World',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.5,
#    'description': "An unlucky, debt-ridden teen resorts to his math skills when he's forced into a deadly tournament of rock-paper-scissors run by a diabolical host.",
#    'type': 'Movie',
#    'country': 'China',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjhjY2E3MzMtZDBmMC00YmJlLWFkMjEtZTZhYjYyNWIyZDVlXkEyXkFqcGdeQXVyODk5NDYzNzM@._V1_SX300.jpg'},
#   {'title': 'Hold the Dark',
#    'rating': 'TV-MA',
#    'imdb_rating': 5.6,
#    'description': 'In the grim Alaskan winter, a naturalist hunts for wolves blamed for killing a local boy, but he soon finds himself swept into a chilling mystery.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjMwOTQ1MzM3M15BMl5BanBnXkFtZTgwODQyNDQxNjM@._V1_SX300.jpg'},
#   {'title': 'Lessons from a School Shooting: Notes from Dunblane',
#    'rating': 'TV-PG',
#    'imdb_rating': None,
#    'description': 'Two priests – one from Dunblane, Scotland, the other from Newtown, Connecticut – bond over school tragedies that occurred 16 years apart.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': None},
#   {'title': 'Made in Mexico',
#    'rating': 'TV-MA',
#    'imdb_rating': 4.0,
#    'description': 'These Mexico City socialites may lead opulent lives, but a peek behind the curtain reveals a tangled web of intrigue, envy and personal struggles.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BY2QyYzc4OGMtYTA1Yi00ODhlLTlkYTAtYjA4OWIxMmFjYjZjXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'Single',
#    'rating': 'TV-PG',
#    'imdb_rating': 6.8,
#    'description': 'Unemployed and immature, a somewhat pathetic bachelor sets his sights on finding a date for the wedding of his younger, more successful brother.',
#    'type': 'Movie',
#    'country': 'Indonesia',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MjA0MTIyNV5BMl5BanBnXkFtZTgwNDMxOTEyNzE@._V1_SX300.jpg'},
#   {'title': 'The 3rd Eye',
#    'rating': 'TV-MA',
#    'imdb_rating': 5.1,
#    'description': 'When her little sister claims she sees the dead, Alia consults a psychic, who opens her own eyes to the vengeful ghosts haunting their childhood home.',
#    'type': 'Movie',
#    'country': 'Indonesia',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNTMyYjc4MjUtMDA0ZS00OGUzLWI5ZTAtMTU4NmVmMGZjNzNhXkEyXkFqcGdeQXVyMzYzOTYxNzM@._V1_SX300.jpg'},
#   {'title': 'The Sinking Of Van Der Wijck',
#    'rating': 'TV-14',
#    'imdb_rating': 7.6,
#    'description': 'When a young man leaves home to fulfill the wishes of his late father, he meets and falls in love with a woman from a very different background.',
#    'type': 'Movie',
#    'country': 'Indonesia',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BY2YwZmFkNzItMDYzZC00N2IzLThjOTYtOWJkNTE0NGExOTY0XkEyXkFqcGdeQXVyMjU0ODQ5NTA@._V1_SX300.jpg'},
#   {'title': 'Two Catalonias',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.4,
#    'description': "Lawmakers and activists with conflicting ideologies speak about the complexities of Catalonia's politics and the fight for its independence from Spain.",
#    'type': 'Movie',
#    'country': 'Spain',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZGJjODM5NWEtMjc0Zi00OTRhLTkzYjYtZDk2NzI1OTkxNGMzXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SX300.jpg'},
#   {'title': 'Bobby Sands: 66 Days',
#    'rating': 'TV-14',
#    'imdb_rating': 7.2,
#    'description': 'In 1981, an imprisoned Irish Republican Army soldier went on a hunger strike that galvanized his movement and made him a controversial global icon.',
#    'type': 'Movie',
#    'country': 'Ireland, United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMmYzYmY2NzgtOWE5ZC00ZmU3LTlmMzAtZTRhMTY1ZTgxOTkzXkEyXkFqcGdeQXVyMzQ5MzI0Mzc@._V1_SX300.jpg'},
#   {'title': 'Bard of Blood',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.0,
#    'description': 'Years after a disastrous job in Balochistan, a former Indian spy must confront his past when he returns to lead an unsanctioned hostage-rescue mission.',
#    'type': 'TV Show',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNjAzZGI0MDctMTgyYi00NDgwLWFmMjgtNTIyMmZhN2FkM2YxXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg'},
#   {'title': 'Deliha 2',
#    'rating': 'TV-PG',
#    'imdb_rating': 4.5,
#    'description': 'While chasing her dream of becoming a chef, Zeliha cooks up trouble in the kitchen with her wild, kooky and unsuspecting ways.',
#    'type': 'Movie',
#    'country': 'Turkey',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYjkzMDYyMDMtOGQ0Yi00ZGNkLWE2NmItNTE2ODI3NjdhMTczXkEyXkFqcGdeQXVyODQ0NTc5NTQ@._V1_SX300.jpg'},
#   {'title': 'Dragons: Rescue Riders',
#    'rating': 'TV-Y',
#    'imdb_rating': 6.1,
#    'description': 'Twins Dak and Leyla and their dragon friends devote their lives to rescuing others, defending their home of Huttsgalor and having fun along the way.',
#    'type': 'TV Show',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYTU1NDc1NWItNWQ0Ni00MzIxLTk0ODktNzRkZTYyZDQyMDg3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'In the Shadow of the Moon',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.2,
#    'description': 'A Philadelphia detective slowly unravels as he nurses a lifelong obsession with an enigmatic female serial killer whose crimes defy explanation.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BN2I1MGQ2ZjMtMjc1My00YzU1LThjNzktNzJlMWRkMTc0NjZhXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg'},
#   {'title': 'Skylines',
#    'rating': 'TV-MA',
#    'imdb_rating': 4.7,
#    'description': 'A hip-hop producer gets hurled into the violent world of organized crime when the record label he signs to becomes the center of a deadly drug business.',
#    'type': 'TV Show',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BY2JmYTlhMWEtM2EyMi00NjU3LTg0MjItZjllMTllZjI4NThjXkEyXkFqcGdeQXVyNjI2ODQwNzQ@._V1_SX300.jpg'},
#   {'title': 'Sturgill Simpson Presents Sound & Fury',
#    'rating': 'TV-MA',
#    'imdb_rating': None,
#    'description': 'In this anime visual album, a mysterious driver heads deep into a postapocalyptic hellscape toward a ferocious showdown with two monstrous opponents.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': None},
#   {'title': 'The Politician',
#    'rating': 'TV-14',
#    'imdb_rating': 7.5,
#    'description': "Rich kid Payton has always known he's going to be president. But first he has to navigate the most treacherous political landscape of all: high school.",
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzk1Yzg4MmEtODFjNS00NzE1LWEzMDItNjhiMmRlYTZhN2U5XkEyXkFqcGdeQXVyMTAxOTg0NDc3._V1_SX300.jpg'},
#   {'title': 'Weeds on Fire',
#    'rating': 'TV-14',
#    'imdb_rating': 6.7,
#    'description': 'In 1980s Hong Kong, a school principal forms a baseball team with an eclectic crew of local students who soon fight their way to the top of the league.',
#    'type': 'Movie',
#    'country': 'Hong Kong',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNmRlNjIxN2QtZTY1OS00MTFhLWFmYzUtZTk5OTE0OGFkZjJkXkEyXkFqcGdeQXVyMjg0MTI5NzQ@._V1_SX300.jpg'},
#   {'title': 'Much Loved',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.2,
#    'description': 'Four friends who make their living as prostitutes in Morocco deal with both the dangers and stigma that come with their profession.',
#    'type': 'Movie',
#    'country': 'France, Morocco',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOTRmNGNlNDktMDU0NC00MGE2LWI4YWEtMDgyNjhhOTM1NmIyXkEyXkFqcGdeQXVyMTc0MTEzMzM@._V1_SX300.jpg'},
#   {'title': 'Joseph: King of Dreams',
#    'rating': 'TV-PG',
#    'imdb_rating': 6.5,
#    'description': 'With his gift of dream interpretation and his brilliantly colored coat, Joseph inspires jealousy in his brothers in this animated Bible story.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZWEzMzg4M2EtYjhmMS00NGYzLWJiZTgtNTg3MGMzOTIxMDAxXkEyXkFqcGdeQXVyNjExODE1MDc@._V1_SX300.jpg'},
#   {'title': 'Malaal',
#    'rating': 'TV-14',
#    'imdb_rating': 5.8,
#    'description': 'Class divides become thorns in the budding romance between the crony of a nativist Mumbai politician and the new, North Indian resident of his chawl.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMWRhNGFhZmYtYWE3ZS00YmE2LThhYTQtZDZjYWMzNmYyZjhhXkEyXkFqcGdeQXVyNjE1OTQ0NjA@._V1_SX300.jpg'},
#   {'title': 'The Grandmaster',
#    'rating': 'PG-13',
#    'imdb_rating': 6.6,
#    'description': "As the Japanese invasion looms, Chinese kung fu master Ip Man's world changes when rival master Gong Er and her father arrive in his village.",
#    'type': 'Movie',
#    'country': 'Hong Kong, China',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZTRiM2VmZTctY2Y0Ni00ZWJmLTg3MGUtMDA3ZmVkYWFkNzJhXkEyXkFqcGdeQXVyMjQ2MTk1OTE@._V1_SX300.jpg'},
#   {'title': 'The Inmate',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.3,
#    'description': "A former Marine poses as an inmate inside a Mexican prison in order to infiltrate a gang suspected of kidnapping a U.S. judge's teen daughter.",
#    'type': 'TV Show',
#    'country': 'Mexico',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOWVlNjhmYmItYjQ5Mi00OTg0LWJmMjktMmYyNWY2MGNhNzY4XkEyXkFqcGdeQXVyNzUxNTczMjc@._V1_SX300.jpg'},
#   {'title': 'The Hurricane Heist',
#    'rating': 'PG-13',
#    'imdb_rating': 5.1,
#    'description': 'A deadly hurricane with mile-high waves provides the perfect cover for stealing $600 million from a U.S. Treasury outpost in Mississippi.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzg3Y2MyNjgtMzk4ZS00OTU3LWEwZmMtN2Y0NTdlZjU0NGFiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'Def Comedy Jam 25',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.6,
#    'description': 'In this special live event, giants of stand-up come together to commemorate the 25th anniversary of Russell Simmons\'s groundbreaking "Def Comedy Jam."',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZWY0MzJjNmItNDc3OS00NzAwLTllM2QtYTQwODM1MTUzY2NmXkEyXkFqcGdeQXVyNTgxMjU0NTk@._V1_SX300.jpg'},
#   {'title': 'Restless Creature: Wendy Whelan',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.1,
#    'description': 'After 30 years with the New York City Ballet, celebrated dancer Wendy Whelan redefines herself as an artist in a new stage of life.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZmNiNDI3MDUtYjhkMS00ZjZjLWFjNjktYjA1ZDhkMmU5NzBjXkEyXkFqcGdeQXVyNzg5MzIyOA@@._V1_SX300.jpg'},
#   {'title': 'Print the Legend',
#    'rating': 'TV-14',
#    'imdb_rating': 7.0,
#    'description': 'This award-winning, original documentary chronicles the race for market leadership in 3D printing, the next wave of technological evolution.',
#    'type': 'Movie',
#    'country': 'United States',
# ...
#    'type': 'Movie',
#    'country': 'Norway, Germany',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNmVhZDY1NDUtN2UzNS00MWViLWEyZjItNmNmODBlOWNhNmYxXkEyXkFqcGdeQXVyNjUxODU0NzU@._V1_SX300.jpg'},
#   {'title': "The President's Barber",
#    'rating': 'TV-MA',
#    'imdb_rating': 6.9,
#    'description': 'The personal barber to the president, as well as his wife and only son, get tangled in the political chaos that gripped South Korea in the late 1900s.',
#    'type': 'Movie',
#    'country': 'South Korea',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOGQwMDRkM2QtMGIzMC00NTJlLThjYTEtZGUwN2VmNTE0YmIyXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_SX300.jpg'},
#   {'title': 'Tokyo Idols',
#    'rating': 'TV-14',
#    'imdb_rating': 6.9,
#    'description': 'This documentary follows J-Pop idol Rio and her predominantly middle-aged fans, and their seemingly transactional interactions.',
#    'type': 'Movie',
#    'country': 'United Kingdom, Canada, Japan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOGFjYzJiN2UtNjgwZi00N2E5LWE3NjItNzZkN2ZmZWQyM2RjXkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SX300.jpg'},
#   {'title': 'Verónica',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.2,
#    'description': "A reclusive psychologist agrees to treat a patient – whose therapist is missing – at her remote cabin, where the women test each other's boundaries.",
#    'type': 'Movie',
#    'country': 'Mexico',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMmRkMDQzYzItZDFhMS00YzM1LTk0ZGMtZmExMzdiNzEwOTE4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'title': 'Welcome to Monster High: The Origin Story',
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': "Dracula's daughter Draculaura sets out to create a new kind of school where monsters of all kinds can be themselves and have a scary good time.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': None},
#   {'title': 'What She Put on the Table',
#    'rating': 'TV-PG',
#    'imdb_rating': 6.8,
#    'description': 'Based on the life of TV chef Fu Pei-mei, this drama follows two women – one rich, the other poor – who fortuitously cross paths in 1950s Taiwan.',
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYTlhNzcxNzItNDZjNS00NDYyLWFkYjItOWI5ZTUwZDhlZjY0XkEyXkFqcGdeQXVyMjg0MTI5NzQ@._V1_SX300.jpg'},
#   {'title': 'Wrong Side Raju',
#    'rating': 'TV-MA',
#    'imdb_rating': 7.9,
#    'description': 'The life of a chauffeur and part-time bootlegger takes a turn toward the dramatic when a girl approaches him to buy illicit alcohol.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNmQ1ZWUxOWUtMTZjYi00Mzc5LTlhZTgtYmJhYmE0ZGQ4ZWI4XkEyXkFqcGdeQXVyMzUwNzg0OQ@@._V1_SX300.jpg'},
#   {'title': 'Be with Me',
#    'rating': 'TV-14',
#    'imdb_rating': 7.0,
#    'description': 'They were the boy band to beat until fame tore them apart. Ten years later, five friends and an ex-love reunite and find themselves closer than ever.',
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMDgxNjk2N15BMl5BanBnXkFtZTcwNTY1NTk3OA@@._V1_SX300.jpg'},
#   {'title': 'Be with You',
#    'rating': 'TV-14',
#    'imdb_rating': 7.9,
#    'description': 'After reconnecting with their girlhood crushes, two sisters find their lives turned upside down by surprising revelations and romantic intrigue.',
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZTNhOWVmM2EtNGZiNC00ZTg3LTk2ODAtMDhhZmY2ZDk1NTg1XkEyXkFqcGdeQXVyMzYwMjQ3OTI@._V1_SX300.jpg'},
#   {'title': 'Bombshell',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.8,
#    'description': 'In 1985, when a vessel protesting nuclear testing is sunk in New Zealand, local police fight to prove it was a terrorist plot by their French allies.',
#    'type': 'Movie',
#    'country': None,
#    'poster': 'https://m.media-amazon.com/images/M/MV5BZjlhOWE3YjktY2MzOC00ZmQ1LWIwNjgtZmVhZmFjZGExMzgyXkEyXkFqcGdeQXVyMDA4NzMyOA@@._V1_SX300.jpg'},
#   {'title': 'Chatô: The King of Brazil',
#    'rating': 'NR',
#    'imdb_rating': 6.1,
#    'description': 'The romanticized life of media mogul Assis Chateaubriand depicts him as the star of a televised trial, where his passions and achievements are judged.',
#    'type': 'Movie',
#    'country': 'Brazil',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNmU0NjFiMzgtYTYxNi00OTcyLTg4MzQtNGExMmMxOTExMjJlXkEyXkFqcGdeQXVyNTU0MjA3NTM@._V1_SX300.jpg'},
#   {'title': "Chewin' the Fat",
#    'rating': 'TV-14',
#    'imdb_rating': 8.2,
#    'description': 'Petty criminals, dodgy decorators, full-bore Glaswegians and oddball documentary presenters converge in this sketch show that parodies Scottish life.',
#    'type': 'TV Show',
#    'country': 'United Kingdom',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTcyOTAyMTYxN15BMl5BanBnXkFtZTcwMTcxNjEzMQ@@._V1_SX300.jpg'},
#   {'title': 'Fall in Love with Me',
#    'rating': 'TV-14',
#    'imdb_rating': 7.1,
#    'description': "The head of a struggling ad agency finds herself torn between a hotshot executive and a kind stranger – not realizing they're the same person.",
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNGEyYzQ3NjAtODdiYy00YzgyLWE1MDItOGQ2N2ZhMWYwYzIxXkEyXkFqcGdeQXVyOTI5NzY5NA@@._V1_SX300.jpg'},
#   {'title': 'Harud',
#    'rating': 'TV-14',
#    'imdb_rating': None,
#    'description': "A young Kashmiri man sets out to escape to Pakistan and make sense of his brother's death, but he drifts aimlessly until finding his brother's camera.",
#    'type': 'Movie',
#    'country': 'India',
#    'poster': None},
#   {'title': 'Love Cheque Charge',
#    'rating': 'TV-14',
#    'imdb_rating': 7.7,
#    'description': 'Three years after making a wild promise to a woman in distress, a rigid businessman runs into her again and must decide whether to honor his word.',
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMDdjNzZlZTgtYjZlMi00NmVjLWIwOWUtMzZlMDJhZWUzZTliL2ltYWdlXkEyXkFqcGdeQXVyMjg0MTI5NzQ@._V1_SX300.jpg'},
#   {'title': "Masha's Spooky Stories",
#    'rating': 'TV-Y',
#    'imdb_rating': 4.8,
#    'description': "Masha explains why there's no need to be scared of things like monsters, the dark, going to a new school, thunder and other common childhood fears.",
#    'type': 'TV Show',
#    'country': 'United States, Russia',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMmIwZTZhNTktNjcxMS00MGU0LTg3YTctYjVjZDA1ZTA5YjVkXkEyXkFqcGdeQXVyMjA4OTQ2OTk@._V1_SX300.jpg'},
#   {'title': 'Much Ado About Nothing',
#    'rating': 'NR',
#    'imdb_rating': 7.3,
#    'description': 'Carefree college student Vicente ends up in a desperate fight for freedom when a well-connected friend falsely accuses him of a hit-and-run accident.',
#    'type': 'Movie',
#    'country': 'Chile, United States, France',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BY2Q3YTU4OTgtZTc0My00YmY1LWJmOTQtMmMwNGE2ZjBmNmIxXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SX300.jpg'},
#   {'title': "Murphy's Law of Love",
#    'rating': 'TV-14',
#    'imdb_rating': 7.4,
#    'description': "An online matchmaker who's convinced she's living under a curse finds her theories on life and love tested when she meets a shrewd divorce expert.",
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOTk4OTVlNTItNDFhOS00ZjZiLTlmZmMtNWY0ZWVmNjE5NTBkL2ltYWdlXkEyXkFqcGdeQXVyMjg0MTI5NzQ@._V1_SX300.jpg'},
#   {'title': 'My Big Night',
#    'rating': 'TV-MA',
#    'imdb_rating': 6.0,
#    'description': "An unemployed man gets a job as an extra at the shooting of a New Year's Eve TV special that's beset by crises and seems to go on forever.",
#    'type': 'Movie',
#    'country': 'Spain',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNTkxZjBiNGItZDY2OS00ZDI4LTgxNTctM2Q4ZDQ1ZTBlYzY3XkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_SX300.jpg'},
#   {'title': 'My Little Pony Equestria Girls: Legend of Everfree',
#    'rating': 'TV-Y7',
#    'imdb_rating': 6.5,
#    'description': 'The Equestria Girls, human teen counterparts to My Little Pony characters, head to Camp Everfree, where they need a little magic to help save summer.',
#    'type': 'Movie',
#    'country': 'United States, Canada',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNTNlYjE5ZTAtMDZjZS00ODk1LTk2N2EtMzcxZDE2NjBlODY3XkEyXkFqcGdeQXVyMTEwOTMwMjk0._V1_SX300.jpg'},
#   {'title': 'Old Money',
#    'rating': 'TV-14',
#    'imdb_rating': 7.4,
#    'description': 'Backstabbing, blackmail and revenge consume the dysfunctional family of a wealthy patriarch as they compete to find him a new liver at all costs.',
#    'type': 'TV Show',
#    'country': 'United States',
#    'poster': None},
#   {'title': "Pac's Scary Halloween",
#    'rating': 'TV-Y7',
#    'imdb_rating': None,
#    'description': 'When sinister Dr. Pacenstein schemes to swap bodies with Pac during a Halloween party, Spiral, Cyli and Count Pacula scramble to save their pal.',
#    'type': 'Movie',
#    'country': None,
#    'poster': None},
#   {'title': 'Riphagen - The Untouchable',
#    'rating': 'NR',
#    'imdb_rating': None,
#    'description': 'This biopic profiles Andries Riphagen, a Dutch criminal who blackmailed Jews in hiding during World War II and was responsible for hundreds of deaths.',
#    'type': 'Movie',
#    'country': 'Netherlands',
#    'poster': None},
#   {'title': 'Robotech',
#    'rating': 'TV-MA',
#    'imdb_rating': 8.5,
#    'description': 'When a mysterious spaceship crashes in the Pacific, the people of Earth work to master the science of robotechnology and rebuild the giant fortress.',
#    'type': 'TV Show',
#    'country': 'United States, Japan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTkwNDA0NjAxN15BMl5BanBnXkFtZTgwMDU5MjAxMzE@._V1_SX300.jpg'},
#   {'title': 'Someone Like You',
#    'rating': 'TV-14',
#    'imdb_rating': 6.1,
#    'description': 'After losing his sight and his fiancee in an accident, a man hires a caregiver who mysteriously sounds – and looks – just like his late girlfriend.',
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BNWIwMGYzOGYtMDY2Yy00NDk5LWI5MTItMDI2YzExMzI4ZDQ0XkEyXkFqcGdeQXVyNTE0MDY4Mjk@._V1_SX300.jpg'},
#   {'title': 'Umrika',
#    'rating': 'TV-14',
#    'imdb_rating': 6.6,
#    'description': 'An ambitious man leaves his small Indian village for America. But when his letters to home stop coming, his brother sets out on his own adventure.',
#    'type': 'Movie',
#    'country': 'India',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BYTY3ZGU0YTMtMmJhMC00ZTJmLTgxNjctMGQ5MTU4Y2RhM2RlXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg'},
#   {'title': 'Unchained: The Untold Story of Freestyle Motocross',
#    'rating': 'NR',
#    'imdb_rating': 7.9,
#    'description': "This adrenaline-rush documentary traces the rise of freestyle motocross, arguably the world's most extreme sport, and spotlights its pioneers.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5NzY0NzU0Nl5BMl5BanBnXkFtZTgwMTcyMzA2MDI@._V1_SX300.jpg'},
#   {'title': 'Welcome Mr. President',
#    'rating': 'TV-14',
#    'imdb_rating': 6.2,
#    'description': "When frustrated politicians name a historical figure as the next president, an honest, humble man by the same name suddenly becomes Italy's leader.",
#    'type': 'Movie',
#    'country': 'Italy',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMzgzMzJjY2YtNzUyOC00ODJiLTg5NTItNWVlMzJhOTkxOWZlXkEyXkFqcGdeQXVyNTA0OTU0OTQ@._V1_SX300.jpg'},
#   {'title': 'When I See You Again',
#    'rating': 'TV-14',
#    'imdb_rating': 7.6,
#    'description': "On a visit to his hometown, a rich bachelor seeks revenge on the woman who broke his heart 10 years ago. But his plan doesn't go as expected.",
#    'type': 'TV Show',
#    'country': 'Taiwan',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMDQyYzJhMjgtMTIzNC00NmNlLWE5MDUtNWEwNzMwZGE1MDdmL2ltYWdlXkEyXkFqcGdeQXVyMjg0MTI5NzQ@._V1_SX300.jpg'},
#   {'title': 'Wakfu: The Quest for the Six Eliatrope Dofus',
#    'rating': 'TV-Y7-FV',
#    'imdb_rating': None,
#    'description': "Six years after Yugo and his team defeat Qilby, Ogrest's crying floods Amalia's kingdom. To stop him, they must find the six missing Eliatrope Dofus.",
#    'type': 'TV Show',
#    'country': 'France',
#    'poster': None},
#   {'title': 'A Stoning in Fulham County',
#    'rating': 'NR',
#    'imdb_rating': 5.8,
#    'description': 'After reckless teens kill an Amish child, a prosecutor attempts to bring the youths to justice despite the condemnation he faces from the community.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTY3MDE0OTY5OV5BMl5BanBnXkFtZTgwMDEwODY0MjE@._V1_SX300.jpg'},
#   {'title': 'Adam: His Song Continues',
#    'rating': 'NR',
#    'imdb_rating': 7.2,
#    'description': 'After their child was abducted and murdered, John and Reve Walsh fought to raise national awareness of the problem of missing children.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMjIwMDc1NTM3OV5BMl5BanBnXkFtZTgwNzAwODY0MjE@._V1_SX300.jpg'},
#   {'title': 'Hard Lessons',
#    'rating': 'NR',
#    'imdb_rating': None,
#    'description': 'This drama based on real-life events tells the story of George McKenna, the tough, determined new principal of a notorious Los Angeles high school.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': None},
#   {'title': 'In Defense of a Married Man',
#    'rating': 'NR',
#    'imdb_rating': 5.6,
#    'description': "A lawyer's husband is having an affair. When his mistress is found dead, he becomes the prime suspect – and his wife must take charge of his defense.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNjA5Njk0Nl5BMl5BanBnXkFtZTgwMTIwODY0MjE@._V1_SX300.jpg'},
#   {'title': 'Quiet Victory: The Charlie Wedemeyer Story',
#    'rating': 'TV-PG',
#    'imdb_rating': 7.3,
#    'description': "When high school football coach Charlie Wedemeyer is diagnosed with Lou Gehrig's disease, he perseveres in leading his team despite becoming disabled.",
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOWIzZjNmMjgtZjU5MC00ODllLTk5YjItY2U2NWM0YWJjZDBjXkEyXkFqcGdeQXVyMTczNjQwOTY@._V1_SX300.jpg'},
#   {'title': 'Strange Voices',
#    'rating': 'NR',
#    'imdb_rating': 6.5,
#    'description': 'When their college-age daughter suddenly begins acting erratically and is diagnosed with schizophrenia, a desperate couple seeks treatment for her.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTU5MTU4MzIxNV5BMl5BanBnXkFtZTgwODAwODY0MjE@._V1_SX300.jpg'},
#   {'title': 'The Ryan White Story',
#    'rating': 'TV-PG',
#    'imdb_rating': 7.3,
#    'description': 'After contracting HIV from a tainted blood treatment, teenaged hemophiliac Ryan White is forced to fight for his right to attend public school.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ0NjI2NTgtZWYxNy00M2JjLWEyODgtY2Q2NzJmMmUyOTE4XkEyXkFqcGdeQXVyMjczOTU2NTI@._V1_SX300.jpg'},
#   {'title': 'Too Young the Hero',
#    'rating': 'NR',
#    'imdb_rating': 6.9,
#    'description': 'Twelve-year-old Calvin manages to join the navy and serves in the battle of Guadalcanal. But when his age is revealed, the boy is sent to the brig.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BOWJjZmE3MmUtZjkyMC00YTAyLThkNWMtMWM2YjhlYjMyY2MyXkEyXkFqcGdeQXVyNzMwOTY2NTI@._V1_SX300.jpg'},
#   {'title': 'Triumph of the Heart',
#    'rating': 'TV-PG',
#    'imdb_rating': 7.4,
#    'description': 'This drama tells the tale of Ricky Bell, a pro running back with the Tampa Bay Buccaneers who died of a muscle disease in the prime of his career.',
#    'type': 'Movie',
#    'country': 'United States',
#    'poster': 'https://m.media-amazon.com/images/M/MV5BMTc2NTQ2MDk1Nl5BMl5BanBnXkFtZTcwNDI1NTkxMQ@@._V1_SX300.jpg'},
#   ...]}
